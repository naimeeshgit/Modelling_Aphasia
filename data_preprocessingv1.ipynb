# %%
import re
import os

# %% [markdown]
# ## Clubbing *INV or *PAR, %wor, %mor, %gra
#
# # from each file, pull out a set of lines that have INV/PAR, wor, mor, gra and club them into one array of 4 sentences along with timecode for the whole sentence
# # append this list into a file list for that particular corpus
# # this file list will be appended to the global list of lists with content from all the files

# %%
def Individual_Club_Structure(club, speaker):
    ind_club = {}
    ind_club["speaker"] = speaker

    chunk = ""
    club_line_num = 0
    for club_line in club.splitlines():
        if club_line.startswith(" %mor"):
            ind_club["dialogue"] = chunk
            chunk = ""
            chunk += club_line + "\n" + " "
            club_line_num = club.splitlines().index(club_line)
            break
        else:
            chunk += club_line + "\n" + " "
    
    for club_line in club.splitlines()[club_line_num:]:
        if club_line.startswith(" %gra"):
            ind_club["mor"] = chunk
            chunk = ""
            chunk += club_line + "\n" + " "
            club_line_num = club.splitlines().index(club_line)
            break
        else:
            chunk += club_line + "\n" + " "
    
    for club_line in club.splitlines()[club_line_num:]:
        if club_line.startswith(" %wor"):
            ind_club["gra"] = chunk
            chunk = ""
            club_line_num = club.splitlines().index(club_line)
            break
        else:
            chunk += club_line + "\n" + " "
    
    for club_line in club.splitlines()[club_line_num:]:
        # iterate till end and add to %wor 
        chunk += club_line + "\n" + " "

        
    ind_club["wor"] = chunk

    return ind_club



def Club(file):
    ''' # structure of file dict: 
        # {
        # "metadata": "<string>", 
        # "clubs":  [
        #               {
        #                   
                            #   "speaker" : "<speaker_type>",
                            #   "dialogue": "<dialogue text>",
                            #   "mor": "<morphology>",
                            #   "gra": "<grammar>",
                            #   "wor": "<word>"
                            
        #               }, 
        #               { }, ...
        #           ]
        # } '''
   
    file_dict = {}

    with open(file, 'r') as f:
        # store whole_text 
        whole_text = f.read()
        
        club = ""
        # first iterate through all meta data until we hit @G
        break_line_num= 0
        for line in whole_text.splitlines():
            if line.startswith("@G"):
                club += line + "\n" + " "
                break_line_num = whole_text.splitlines().index(line)
                break
            else:
                club += line + "\n" + " "
        
        # store meta data in file_list under "metadata"
        file_dict["metadata"] = club
        # print("metadata: ", file_dict["metadata"])

        # iterate through all clubs from break_line_num to end using:
            # use a for loop to add lines to club from *PAR until we hit *INV or *PAR
            # *INV , *PAR mark the begining of a dialogue
            # %wor, %mor, gra -> breaks down the sentence and list its qualities like morphology and grammar
            # keep adding strings to club until we hit a new dialogue represented by *PAR or *INV
        file_dict["clubs"] = []
        club = ""
        i=0
        speaker = ""
        for line in whole_text.splitlines()[break_line_num+1:]:
            # print(line)
            if (line.startswith("*INV") or line.startswith("*PAR")) and club == "":
                if line.startswith("*INV"):
                    speaker = "INV"
                else:
                    speaker = "PAR"

            if (line.startswith("*INV") or line.startswith("*PAR")) and club!="":
                # iterate the club and chunk it based on dialogues begining with:
                    # *INV or *PAR
                    # *mor
                    # *gra
                    # *wor
                
                # iterate through club and chunk it based on dialogues
                # speaker type identified by checking if it starts with *INV or *PAR in the above if check
                # dialogue = chunk that is between *INV to %mor 
                # mor = chunk that is between %mor to %gra
                # gra = chunk that is between %gra to %wor
               
                ind_club = Individual_Club_Structure(club,speaker)
                file_dict["clubs"].append(ind_club)
    
                club = ""
                club += line + "\n" + " "
                if line.startswith("*INV"):
                    speaker = "INV"
                else:
                    speaker = "PAR"
            else:
                club += line + "\n" + " "
        
        # add last club to file_list
        file_dict["clubs"].append(Individual_Club_Structure(club, speaker))

    return file_dict

file_list = Club('./English_Protocol_Aphasia/Garrett/garrett01a.cha')

# print file list in a formatted way
import json
print(json.dumps(file_list, indent=4))
# Out:
# {
#     "metadata": "@UTF8\n @PID:\t11312/t-00017896-1\n @Window:\t444_913_770_1024_-1_-1_1541_0_1541_0\n @Begin\n @Languages:\teng\n @Participants:\tPAR garrett01a Participant, INV Investigator\n @Options:\tmulti\n @ID:\teng|Garrett|PAR|76;08.|female|Wernicke||Participant||52.4|\n @ID:\teng|Garrett|INV|||||Investigator|||\n @Media:\tgarrett01a, video\n *INV:\twww .\n %wor:\twww .\n %exp:\tconversation before protocol begins\n @G:\tWindow\n ",
#     "clubs": [
#         {
#             "speaker": "INV",
#             "dialogue": "*INV:\twe'll start with part two picture descriptions . \u001520730_24860\u0015\n ",
#             "mor": " %mor:\tpro:sub|we~mod|will v|start prep|with n|part det:num|two n|picture\n  %mor:\tpro:sub|we~mod|will v|start prep|with n|part det:num|two n|picture\n  \tn|description-PL .\n ",
#             "gra": " %gra:\t1|3|SUBJ 2|3|AUX 3|0|ROOT 4|3|JCT 5|8|MOD 6|7|QUANT 7|8|MOD 8|4|POBJ\n  %gra:\t1|3|SUBJ 2|3|AUX 3|0|ROOT 4|3|JCT 5|8|MOD 6|7|QUANT 7|8|MOD 8|4|POBJ\n  \t9|3|PUNCT\n ",
#             "wor": " %wor:\twe'll \u001520730_20830\u0015 start \u001520830_21410\u0015 with \u001521410_21980\u0015 part \u001522100_22460\u0015 two \u001522460_23070\u0015 picture \u001523100_23520\u0015 descriptions \u001523520_24860\u0015 .\n  \n "
#         },
#         {
#             "speaker": "INV",
#             "dialogue": "*INV:\tcan you tell me a story <about what's> [>1] <going on in these>\n  \t[>2] pictures [>3] ? \u001525979_34439\u0015\n ",
#             "mor": " %mor:\tmod|can pro:per|you v|tell pro:obj|me det:art|a n|story prep|about\n  %mor:\tmod|can pro:per|you v|tell pro:obj|me det:art|a n|story prep|about\n  \tpro:int|what~aux|be&3S part|go-PRESP adv|on prep|in det:dem|these\n  \tn|picture-PL ?\n ",
#             "gra": " %gra:\t1|3|AUX 2|3|SUBJ 3|0|ROOT 4|3|OBJ2 5|6|DET 6|3|OBJ 7|3|JCT 8|10|LINK\n  %gra:\t1|3|AUX 2|3|SUBJ 3|0|ROOT 4|3|OBJ2 5|6|DET 6|3|OBJ 7|3|JCT 8|10|LINK\n  \t9|10|AUX 10|7|CPOBJ 11|10|JCT 12|10|JCT 13|14|DET 14|12|POBJ 15|3|PUNCT\n ",
#             "wor": " %wor:\tcan \u001525979_26079\u0015 you \u001529509_29759\u0015 tell \u001529759_30159\u0015 me \u001530159_30389\u0015 a \u001530389_30429\u0015 story \u001530429_31529\u0015 <about \u001531819_32049\u0015 what's \u001532049_32339\u0015> [>1] <going on in these>  [>2] \u001532339_33659\u0015 pictures [>3] \u001533659_34439\u0015 ?\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\t<&=head:yes mhm yeah> [<1] . [+ exc] \u001533660_33661\u0015\n ",
#             "mor": " %mor:\tco|mhm=yes co|yeah .\n  %mor:\tco|mhm=yes co|yeah .\n ",
#             "gra": " %gra:\t1|2|COM 2|0|INCROOT 3|2|PUNCT\n  %gra:\t1|2|COM 2|0|INCROOT 3|2|PUNCT\n ",
#             "wor": " %wor:\t<&=head:yes mhm \u001531815_32085\u0015 yeah \u001532085_32515\u0015> [<1] . [+ exc]\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\t<&=head:yes uhhuh> [<3] . [+ exc] \u001533809_33939\u0015\n ",
#             "mor": " %mor:\tco|uhhuh .\n  %mor:\tco|uhhuh .\n ",
#             "gra": " %gra:\t1|0|INCROOT 2|1|PUNCT\n  %gra:\t1|0|INCROOT 2|1|PUNCT\n ",
#             "wor": " %wor:\t<&=head:yes uhhuh \u001533809_33939\u0015> [<3] . [+ exc]\n  \n "
#         },
#         {
#             "speaker": "INV",
#             "dialogue": "*INV:\tready ? \u001534573_34973\u0015\n ",
#             "mor": " %mor:\tadj|ready ?\n  %mor:\tadj|ready ?\n ",
#             "gra": " %gra:\t1|0|INCROOT 2|1|PUNCT\n  %gra:\t1|0|INCROOT 2|1|PUNCT\n ",
#             "wor": " %wor:\tready \u001534573_34973\u0015 ?\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\t&=head:yes yeah . [+ exc] \u001535066_35316\u0015\n ",
#             "mor": " %mor:\tco|yeah .\n  %mor:\tco|yeah .\n ",
#             "gra": " %gra:\t1|0|INCROOT 2|1|PUNCT\n  %gra:\t1|0|INCROOT 2|1|PUNCT\n ",
#             "wor": " %wor:\t&=head:yes yeah \u001535066_35316\u0015 . [+ exc]\n  \n "
#         },
#         {
#             "speaker": "INV",
#             "dialogue": "*INV:\t+< go . \u001535526_35586\u0015\n ",
#             "mor": " %mor:\tv|go .\n  %mor:\tv|go .\n ",
#             "gra": " %gra:\t1|0|ROOT 2|1|PUNCT\n  %gra:\t1|0|ROOT 2|1|PUNCT\n ",
#             "wor": " %wor:\t+< go \u001535526_35586\u0015 .\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\t&=points:picture_one this bog [* s:uk] is by the bog [* s:uk] is\n  \tgot &=ges xxx . [+ jar] \u001536378_39158\u0015\n ",
#             "mor": " %mor:\tdet:dem|this n|bog cop|be&3S prep|by det:art|the n|bog aux|be&3S\n  %mor:\tdet:dem|this n|bog cop|be&3S prep|by det:art|the n|bog aux|be&3S\n  \tpart|get&PASTP .\n ",
#             "gra": " %gra:\t1|2|DET 2|3|SUBJ 3|0|ROOT 4|8|JCT 5|6|DET 6|8|SUBJ 7|8|AUX 8|3|CJCT\n  %gra:\t1|2|DET 2|3|SUBJ 3|0|ROOT 4|8|JCT 5|6|DET 6|8|SUBJ 7|8|AUX 8|3|CJCT\n  \t9|3|PUNCT\n ",
#             "wor": " %wor:\t&=points:picture_one this \u001536378_36578\u0015 bog [* s:uk] \u001536578_37008\u0015 is \u001537168_37338\u0015 by \u001537668_37898\u0015 the \u001537898_37998\u0015 bog [* s:uk] \u001538198_38648\u0015 is \u001538648_38768\u0015  got \u001538898_39158\u0015 &=ges xxx . [+ jar]\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\tand he said +\"/. \u001539321_39791\u0015\n ",
#             "mor": " %mor:\tcoord|and pro:sub|he v|say&PAST +\"/.\n  %mor:\tcoord|and pro:sub|he v|say&PAST +\"/.\n ",
#             "gra": " %gra:\t1|3|LINK 2|3|SUBJ 3|0|ROOT 4|3|PUNCT\n  %gra:\t1|3|LINK 2|3|SUBJ 3|0|ROOT 4|3|PUNCT\n ",
#             "wor": " %wor:\tand \u001539321_39501\u0015 he \u001539501_39611\u0015 said \u001539611_39791\u0015 +\"/.\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\t+\" &=ges:surprise oh_my_gosh xxx . [+ jar] \u001540087_41657\u0015\n ",
#             "mor": " %mor:\tco|oh_my_gosh .\n  %mor:\tco|oh_my_gosh .\n ",
#             "gra": " %gra:\t1|0|INCROOT 2|1|PUNCT\n  %gra:\t1|0|INCROOT 2|1|PUNCT\n ",
#             "wor": " %wor:\t+\" &=ges:surprise oh_my_gosh \u001540087_41657\u0015 xxx . [+ jar]\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\t&=points:picture_two g\u028c\u027e\u0259@u [: x@n] [* n:uk] . [+ jar] \u001542121_42311\u0015\n ",
#             "mor": " %mor:\tneo|x .\n  %mor:\tneo|x .\n ",
#             "gra": " %gra:\t1|0|INCROOT 2|1|PUNCT\n  %gra:\t1|0|INCROOT 2|1|PUNCT\n ",
#             "wor": " %wor:\t&=points:picture_two g\u028c\u027e\u0259@u [: x@n] [* n:uk] \u001542121_42311\u0015 . [+ jar]\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\t&=points:picture_three and a m\u0254t@u [: x@n] [* n:uk] p\u0254@u [: x@n]\n  \t[* n:uk] . [+ jar] \u001543103_44263\u0015\n ",
#             "mor": " %mor:\tcoord|and det:art|a neo|x neo|x .\n  %mor:\tcoord|and det:art|a neo|x neo|x .\n ",
#             "gra": " %gra:\t1|4|LINK 2|4|DET 3|4|MOD 4|0|ROOT 5|4|PUNCT\n  %gra:\t1|4|LINK 2|4|DET 3|4|MOD 4|0|ROOT 5|4|PUNCT\n ",
#             "wor": " %wor:\t&=points:picture_three and \u001543103_43313\u0015 a \u001543313_43673\u0015 m\u0254t@u [: x@n] [* n:uk] \u001544203_44233\u0015 p\u0254@u [: x@n]  [* n:uk] \u001544233_44263\u0015 . [+ jar]\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\t&=points:picture_three a sp\u00e6z\u0259lw\u0251t@u [: x@n] [* n:uk] and\n  \t\u00e6lzogl\u00e6d@u [: x@n] [* n:uk] &=ges . [+ jar] \u001545046_47136\u0015\n ",
#             "mor": " %mor:\tdet:art|a neo|x coord|and neo|x .\n  %mor:\tdet:art|a neo|x coord|and neo|x .\n ",
#             "gra": " %gra:\t1|2|DET 2|0|INCROOT 3|2|CONJ 4|3|COORD 5|2|PUNCT\n  %gra:\t1|2|DET 2|0|INCROOT 3|2|CONJ 4|3|COORD 5|2|PUNCT\n ",
#             "wor": " %wor:\t&=points:picture_three a \u001545046_45866\u0015 sp\u00e6z\u0259lw\u0251t@u [: x@n] [* n:uk] \u001546096_46126\u0015 and \u001546126_46766\u0015  \u00e6lzogl\u00e6d@u [: x@n] [* n:uk] \u001546806_47136\u0015 &=ges . [+ jar]\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\tand he looks out the wed [: window] [* s:ur] . \u001547451_48701\u0015\n ",
#             "mor": " %mor:\tcoord|and pro:sub|he v|look-3S prep|out det:art|the n|window .\n  %mor:\tcoord|and pro:sub|he v|look-3S prep|out det:art|the n|window .\n ",
#             "gra": " %gra:\t1|3|LINK 2|3|SUBJ 3|0|ROOT 4|3|JCT 5|6|DET 6|4|POBJ 7|3|PUNCT\n  %gra:\t1|3|LINK 2|3|SUBJ 3|0|ROOT 4|3|JCT 5|6|DET 6|4|POBJ 7|3|PUNCT\n ",
#             "wor": " %wor:\tand \u001547451_47621\u0015 he \u001547621_47691\u0015 looks \u001547691_48051\u0015 out \u001548051_48261\u0015 the \u001548261_48321\u0015 wed [: window] [* s:ur] \u001548321_48701\u0015 .\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\the said +\"/. \u001548795_49265\u0015\n ",
#             "mor": " %mor:\tpro:sub|he v|say&PAST +\"/.\n  %mor:\tpro:sub|he v|say&PAST +\"/.\n ",
#             "gra": " %gra:\t1|2|SUBJ 2|0|ROOT 3|2|PUNCT\n  %gra:\t1|2|SUBJ 2|0|ROOT 3|2|PUNCT\n ",
#             "wor": " %wor:\the \u001548795_48805\u0015 said \u001549125_49265\u0015 +\"/.\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\t+\" well \u2021 it's l\u0254\u014bg\u026at@u [: x@n] [* n:uk] . [+ jar] \u001549564_50694\u0015\n ",
#             "mor": " %mor:\tco|well beg|beg pro:per|it~cop|be&3S neo|x .\n  %mor:\tco|well beg|beg pro:per|it~cop|be&3S neo|x .\n ",
#             "gra": " %gra:\t1|0|BEG 2|1|BEGP 3|4|SUBJ 4|0|ROOT 5|4|PRED 6|4|PUNCT\n  %gra:\t1|0|BEG 2|1|BEGP 3|4|SUBJ 4|0|ROOT 5|4|PRED 6|4|PUNCT\n ",
#             "wor": " %wor:\t+\" well \u001549564_49944\u0015 \u2021 it's \u001549944_50214\u0015 l\u0254\u014bg\u026at@u [: x@n] [* n:uk] \u001550664_50694\u0015 . [+ jar]\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\t&=points he has got the boy [: ball] [* p:w] . \u001551470_52420\u0015\n ",
#             "mor": " %mor:\tpro:sub|he aux|have&3S part|get&PASTP det:art|the n|ball .\n  %mor:\tpro:sub|he aux|have&3S part|get&PASTP det:art|the n|ball .\n ",
#             "gra": " %gra:\t1|3|SUBJ 2|3|AUX 3|0|ROOT 4|5|DET 5|3|OBJ 6|3|PUNCT\n  %gra:\t1|3|SUBJ 2|3|AUX 3|0|ROOT 4|5|DET 5|3|OBJ 6|3|PUNCT\n ",
#             "wor": " %wor:\t&=points he \u001551470_51650\u0015 has \u001551650_51780\u0015 got \u001551780_52180\u0015 the \u001552180_52190\u0015 boy [: ball] [* p:w] \u001552190_52420\u0015 .\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\t&=ges he doesn't know what to do . \u001552635_53595\u0015\n ",
#             "mor": " %mor:\tpro:sub|he mod|do&3S~neg|not v|know pro:int|what inf|to v|do .\n  %mor:\tpro:sub|he mod|do&3S~neg|not v|know pro:int|what inf|to v|do .\n ",
#             "gra": " %gra:\t1|4|SUBJ 2|4|AUX 3|2|NEG 4|0|ROOT 5|7|LINK 6|7|INF 7|4|COMP 8|4|PUNCT\n  %gra:\t1|4|SUBJ 2|4|AUX 3|2|NEG 4|0|ROOT 5|7|LINK 6|7|INF 7|4|COMP 8|4|PUNCT\n ",
#             "wor": " %wor:\t&=ges he \u001552635_52735\u0015 doesn't \u001552735_53125\u0015 know \u001553125_53165\u0015 what \u001553165_53465\u0015 to \u001553465_53525\u0015 do \u001553525_53595\u0015 .\n  \n "
#         },
#         {
#             "speaker": "INV",
#             "dialogue": "*INV:\tright . \u001553900_54260\u0015\n ",
#             "mor": " %mor:\tco|right .\n  %mor:\tco|right .\n ",
#             "gra": " %gra:\t1|0|INCROOT 2|1|PUNCT\n  %gra:\t1|0|INCROOT 2|1|PUNCT\n ",
#             "wor": " %wor:\tright \u001553900_54260\u0015 .\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "gra": "*PAR:\t&=laughs . [+ exc]\n  %wor:\t&=laughs . [+ exc]\n  \n *PAR:\t&=laughs . [+ exc]\n  %wor:\t&=laughs . [+ exc]\n  \n *PAR:\t&=laughs . [+ exc]\n ",
#             "wor": " %wor:\t&=laughs . [+ exc]\n  \n "
#         },
#         {
#             "speaker": "INV",
#             "dialogue": "*INV:\tthat's exactly right . \u001554784_55984\u0015\n ",
#             "mor": " %mor:\tpro:dem|that~cop|be&3S adv|exact&dadj-LY co|right .\n  %mor:\tpro:dem|that~cop|be&3S adv|exact&dadj-LY co|right .\n ",
#             "gra": " %gra:\t1|2|SUBJ 2|0|ROOT 3|2|JCT 4|2|COM 5|2|PUNCT\n  %gra:\t1|2|SUBJ 2|0|ROOT 3|2|JCT 4|2|COM 5|2|PUNCT\n ",
#             "wor": " %wor:\tthat's \u001554784_55034\u0015 exactly \u001555034_55674\u0015 right \u001555674_55984\u0015 .\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\tuhhuh . [+ exc] \u001556305_56545\u0015\n ",
#             "mor": " %mor:\tco|uhhuh .\n  %mor:\tco|uhhuh .\n ",
#             "gra": " %gra:\t1|0|INCROOT 2|1|PUNCT\n  %gra:\t1|0|INCROOT 2|1|PUNCT\n ",
#             "wor": " %wor:\tuhhuh \u001556305_56545\u0015 . [+ exc]\n  \n "
#         },
#         {
#             "speaker": "INV",
#             "dialogue": "*INV:\t+< that was a great rendition . \u001556499_57979\u0015\n ",
#             "mor": " %mor:\tpro:dem|that cop|be&PAST&13S det:art|a adj|great n|rendition .\n  %mor:\tpro:dem|that cop|be&PAST&13S det:art|a adj|great n|rendition .\n ",
#             "gra": " %gra:\t1|2|SUBJ 2|0|ROOT 3|5|DET 4|5|MOD 5|2|PRED 6|2|PUNCT\n  %gra:\t1|2|SUBJ 2|0|ROOT 3|5|DET 4|5|MOD 5|2|PRED 6|2|PUNCT\n ",
#             "wor": " %wor:\t+< that \u001556499_56649\u0015 was \u001556649_56809\u0015 a \u001556809_56859\u0015 great \u001556859_57169\u0015 rendition \u001557169_57979\u0015 .\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\tyeah . [+ exc] \u001558071_58251\u0015\n ",
#             "mor": " %mor:\tco|yeah .\n  %mor:\tco|yeah .\n ",
#             "gra": " %gra:\t1|0|INCROOT 2|1|PUNCT\n  %gra:\t1|0|INCROOT 2|1|PUNCT\n ",
#             "wor": " %wor:\tyeah \u001558071_58251\u0015 . [+ exc]\n  \n "
#         },
#         {
#             "speaker": "INV",
#             "dialogue": "*INV:\t+, of the Broken_Window . \u001558303_59423\u0015\n ",
#             "mor": " %mor:\tprep|of det:art|the n:prop|Broken_Window .\n  %mor:\tprep|of det:art|the n:prop|Broken_Window .\n ",
#             "gra": " %gra:\t1|0|INCROOT 2|3|DET 3|1|POBJ 4|1|PUNCT\n  %gra:\t1|0|INCROOT 2|3|DET 3|1|POBJ 4|1|PUNCT\n ",
#             "wor": " %wor:\t+, of \u001558303_58443\u0015 the \u001558443_58463\u0015 Broken_Window \u001558463_59423\u0015 .\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\tyeah \u2021 I'll bet &=laughs . [+ exc] \u001559806_61026\u0015\n ",
#             "mor": " %mor:\tco|yeah beg|beg pro:sub|I~mod|will v|bet&ZERO .\n  %mor:\tco|yeah beg|beg pro:sub|I~mod|will v|bet&ZERO .\n ",
#             "gra": " %gra:\t1|0|BEG 2|1|BEGP 3|5|SUBJ 4|5|AUX 5|0|ROOT 6|5|PUNCT\n  %gra:\t1|0|BEG 2|1|BEGP 3|5|SUBJ 4|5|AUX 5|0|ROOT 6|5|PUNCT\n ",
#             "wor": " %wor:\tyeah \u001559806_60316\u0015 \u2021 I'll \u001560386_60516\u0015 bet \u001560806_61026\u0015 &=laughs . [+ exc]\n  \n "
#         },
#         {
#             "speaker": "INV",
#             "dialogue": "*INV:\tokay . \u001561675_61765\u0015\n ",
#             "mor": " %mor:\tco|okay .\n  %mor:\tco|okay .\n ",
#             "gra": " %gra:\t1|0|INCROOT 2|1|PUNCT\n  %gra:\t1|0|INCROOT 2|1|PUNCT\n ",
#             "wor": " %wor:\tokay \u001561675_61765\u0015 .\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\t+< all that and he looks &=ges:anger &=points:picture_four +\"/. \u001561881_62701\u0015\n ",
#             "mor": " %mor:\tqn|all pro:dem|that coord|and pro:sub|he v|look-3S +\"/.\n  %mor:\tqn|all pro:dem|that coord|and pro:sub|he v|look-3S +\"/.\n ",
#             "gra": " %gra:\t1|2|QUANT 2|0|ROOT 3|5|LINK 4|5|SUBJ 5|2|CJCT 6|2|PUNCT\n  %gra:\t1|2|QUANT 2|0|ROOT 3|5|LINK 4|5|SUBJ 5|2|CJCT 6|2|PUNCT\n ",
#             "wor": " %wor:\t+< all \u001561881_61941\u0015 that \u001561941_62191\u0015 and \u001562191_62351\u0015 he \u001562351_62391\u0015 looks \u001562391_62701\u0015 &=ges:anger &=points:picture_four +\"/.\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\t+\" we\u028a@u [: x@n] [* n:uk] is he doin(g) &=laughs ? [+ jar] \u001563436_64245\u0015\n ",
#             "mor": " %mor:\tneo|x cop|be&3S pro:sub|he part|do-PRESP ?\n  %mor:\tneo|x cop|be&3S pro:sub|he part|do-PRESP ?\n ",
#             "gra": " %gra:\t1|2|SUBJ 2|0|ROOT 3|4|SUBJ 4|2|PRED 5|2|PUNCT\n  %gra:\t1|2|SUBJ 2|0|ROOT 3|4|SUBJ 4|2|PRED 5|2|PUNCT\n ",
#             "wor": " %wor:\t+\" we\u028a@u [: x@n] [* n:uk] \u001563436_63446\u0015 is \u001563446_63746\u0015 he \u001563746_63916\u0015 doin(g) \u001563946_64246\u0015 &=laughs ? [+ jar]\n  \n "
#         },
#         {
#             "speaker": "INV",
#             "dialogue": "*INV:\t+< &=head:yes yes \u2021 he does &=laughs . \u001564443_65833\u0015\n ",
#             "mor": " %mor:\tco|yes beg|beg pro:sub|he v|do&3S .\n  %mor:\tco|yes beg|beg pro:sub|he v|do&3S .\n ",
#             "gra": " %gra:\t1|0|BEG 2|1|BEGP 3|4|SUBJ 4|0|ROOT 5|4|PUNCT\n  %gra:\t1|0|BEG 2|1|BEGP 3|4|SUBJ 4|0|ROOT 5|4|PUNCT\n ",
#             "wor": " %wor:\t+< &=head:yes yes \u001564443_64803\u0015 \u2021 he \u001564803_65143\u0015 does \u001565143_65833\u0015 &=laughs .\n  \n "
#         },
#         {
#             "speaker": "INV",
#             "dialogue": "*INV:\tI agree with you . \u001565848_67068\u0015\n ",
#             "mor": " %mor:\tpro:sub|I v|agree prep|with pro:per|you .\n  %mor:\tpro:sub|I v|agree prep|with pro:per|you .\n ",
#             "gra": " %gra:\t1|2|SUBJ 2|0|ROOT 3|2|JCT 4|3|POBJ 5|2|PUNCT\n  %gra:\t1|2|SUBJ 2|0|ROOT 3|2|JCT 4|3|POBJ 5|2|PUNCT\n ",
#             "wor": " %wor:\tI \u001565848_66058\u0015 agree \u001566058_66458\u0015 with \u001566458_66708\u0015 you \u001566708_67068\u0015 .\n  @G:\tUmbrella\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\t&=points:pictures and this is so funny . [+ exc] \u001567400_68420\u0015\n ",
#             "mor": " %mor:\tcoord|and pro:dem|this cop|be&3S adv|so adj|fun&dn-Y .\n  %mor:\tcoord|and pro:dem|this cop|be&3S adv|so adj|fun&dn-Y .\n ",
#             "gra": " %gra:\t1|3|LINK 2|3|SUBJ 3|0|ROOT 4|5|JCT 5|3|PRED 6|3|PUNCT\n  %gra:\t1|3|LINK 2|3|SUBJ 3|0|ROOT 4|5|JCT 5|3|PRED 6|3|PUNCT\n ",
#             "wor": " %wor:\t&=points:pictures and \u001567400_67540\u0015 this \u001567540_67720\u0015 is \u001567720_67840\u0015 so \u001567840_68100\u0015 funny \u001568250_68420\u0015 . [+ exc]\n  \n "
#         },
#         {
#             "speaker": "INV",
#             "dialogue": "*INV:\tyep \u2021 and this is another story +/. \u001569091_70961\u0015\n ",
#             "mor": " %mor:\tco|yep beg|beg coord|and pro:dem|this cop|be&3S qn|another n|story\n  %mor:\tco|yep beg|beg coord|and pro:dem|this cop|be&3S qn|another n|story\n  \t+/.\n ",
#             "gra": " %gra:\t1|0|BEG 2|1|BEGP 3|5|LINK 4|5|SUBJ 5|0|ROOT 6|7|QUANT 7|5|PRED\n  %gra:\t1|0|BEG 2|1|BEGP 3|5|LINK 4|5|SUBJ 5|0|ROOT 6|7|QUANT 7|5|PRED\n  \t8|5|PUNCT\n ",
#             "wor": " %wor:\tyep \u001569091_69371\u0015 \u2021 and \u001569371_69511\u0015 this \u001569511_69701\u0015 is \u001569701_69831\u0015 another \u001569831_70191\u0015 story \u001570191_70961\u0015 +/.\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\t+< &=laughs cute . [+ exc] \u001571858_72008\u0015\n ",
#             "mor": " %mor:\tadj|cute .\n  %mor:\tadj|cute .\n ",
#             "gra": " %gra:\t1|0|INCROOT 2|1|PUNCT\n  %gra:\t1|0|INCROOT 2|1|PUNCT\n ",
#             "wor": " %wor:\t+< &=laughs cute \u001571858_72008\u0015 . [+ exc]\n  \n "
#         },
#         {
#             "speaker": "INV",
#             "dialogue": "*INV:\t+, called Refused_Umbrella . \u001572601_74601\u0015\n ",
#             "mor": " %mor:\tpart|call-PASTP n:prop|Refused_Umbrella .\n  %mor:\tpart|call-PASTP n:prop|Refused_Umbrella .\n ",
#             "gra": " %gra:\t1|0|INCROOT 2|1|OBJ 3|1|PUNCT\n  %gra:\t1|0|INCROOT 2|1|OBJ 3|1|PUNCT\n ",
#             "wor": " %wor:\t+, called \u001572601_72791\u0015 Refused_Umbrella \u001572791_74601\u0015 .\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\tI know . [+ exc] \u001575177_75397\u0015\n ",
#             "mor": " %mor:\tpro:sub|I v|know .\n  %mor:\tpro:sub|I v|know .\n ",
#             "gra": " %gra:\t1|2|SUBJ 2|0|ROOT 3|2|PUNCT\n  %gra:\t1|2|SUBJ 2|0|ROOT 3|2|PUNCT\n ",
#             "wor": " %wor:\tI \u001575177_75187\u0015 know \u001575187_75397\u0015 . [+ exc]\n  \n "
#         },
#         {
#             "speaker": "INV",
#             "dialogue": "*INV:\tcan you start here and tell us this story ? \u001575532_78562\u0015\n ",
#             "mor": " %mor:\tmod|can pro:per|you v|start adv|here coord|and v|tell pro:obj|us\n  %mor:\tmod|can pro:per|you v|start adv|here coord|and v|tell pro:obj|us\n  \tdet:dem|this n|story ?\n ",
#             "gra": " %gra:\t1|3|AUX 2|3|SUBJ 3|0|ROOT 4|3|JCT 5|3|CONJ 6|5|COORD 7|6|OBJ 8|9|DET\n  %gra:\t1|3|AUX 2|3|SUBJ 3|0|ROOT 4|3|JCT 5|3|CONJ 6|5|COORD 7|6|OBJ 8|9|DET\n  \t9|6|OBJ 10|3|PUNCT\n ",
#             "wor": " %wor:\tcan \u001575532_75682\u0015 you \u001575682_75742\u0015 start \u001575742_76192\u0015 here \u001576232_76792\u0015 and \u001576822_77212\u0015 tell \u001577212_77492\u0015 us \u001577492_77702\u0015 this \u001577702_77862\u0015 story \u001577862_78562\u0015 ?\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\t&=points:picture_one so \u2021 this he says is \u00f0\u00e6\u027e\u026a@u [: x@n] [* n:uk] .\n  \t[+ jar] \u001579153_80803\u0015\n ",
#             "mor": " %mor:\tco|so beg|beg pro:dem|this pro:sub|he v|say-3S cop|be&3S neo|x .\n  %mor:\tco|so beg|beg pro:dem|this pro:sub|he v|say-3S cop|be&3S neo|x .\n ",
#             "gra": " %gra:\t1|0|BEG 2|1|BEGP 3|6|SUBJ 4|5|SUBJ 5|3|CMOD 6|0|ROOT 7|6|PRED 8|6|PUNCT\n  %gra:\t1|0|BEG 2|1|BEGP 3|6|SUBJ 4|5|SUBJ 5|3|CMOD 6|0|ROOT 7|6|PRED 8|6|PUNCT\n ",
#             "wor": " %wor:\t&=points:picture_one so \u001579153_79453\u0015 \u2021 this \u001579453_79763\u0015 he \u001579763_79883\u0015 says \u001579883_80253\u0015 is \u001580253_80433\u0015 \u00f0\u00e6\u027e\u026a@u [: x@n] [* n:uk] \u001580583_80803\u0015 .  [+ jar]\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\the says +\"/. \u001580894_81264\u0015\n ",
#             "mor": " %mor:\tpro:sub|he v|say-3S +\"/.\n  %mor:\tpro:sub|he v|say-3S +\"/.\n ",
#             "gra": " %gra:\t1|2|SUBJ 2|0|ROOT 3|2|PUNCT\n  %gra:\t1|2|SUBJ 2|0|ROOT 3|2|PUNCT\n ",
#             "wor": " %wor:\the \u001580894_81044\u0015 says \u001581044_81264\u0015 +\"/.\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\t+\" &=hand:no no [/] no [/] no [/] no . \u001581458_82198\u0015\n ",
#             "mor": " %mor:\tco|no .\n  %mor:\tco|no .\n ",
#             "gra": " %gra:\t1|0|INCROOT 2|1|PUNCT\n  %gra:\t1|0|INCROOT 2|1|PUNCT\n ",
#             "wor": " %wor:\t+\" &=hand:no no [/] \u001581458_81518\u0015 no [/] \u001581518_81898\u0015 no [/] \u001581968_82028\u0015 no \u001582028_82198\u0015  .\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\t&=points:picture_two he &ge gets \u00f0\u028cm@u [: x@n] [* n:uk] . [+ jar] \u001582967_84007\u0015\n ",
#             "mor": " %mor:\tpro:sub|he v|get-3S neo|x .\n  %mor:\tpro:sub|he v|get-3S neo|x .\n ",
#             "gra": " %gra:\t1|2|SUBJ 2|0|ROOT 3|2|OBJ 4|2|PUNCT\n  %gra:\t1|2|SUBJ 2|0|ROOT 3|2|OBJ 4|2|PUNCT\n ",
#             "wor": " %wor:\t&=points:picture_two he \u001582967_83217\u0015 &ge gets \u001583687_83927\u0015 \u00f0\u028cm@u [: x@n] [* n:uk] \u001583927_84007\u0015 . [+ jar]\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\the said +\"/. \u001584400_84590\u0015\n ",
#             "mor": " %mor:\tpro:sub|he v|say&PAST +\"/.\n  %mor:\tpro:sub|he v|say&PAST +\"/.\n ",
#             "gra": " %gra:\t1|2|SUBJ 2|0|ROOT 3|2|PUNCT\n  %gra:\t1|2|SUBJ 2|0|ROOT 3|2|PUNCT\n ",
#             "wor": " %wor:\the \u001584400_84520\u0015 said \u001584520_84590\u0015 +\"/.\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\t+\" &=ges well \u2021 here I get it . \u001584820_85630\u0015\n ",
#             "mor": " %mor:\tco|well beg|beg adv|here pro:sub|I v|get pro:per|it .\n  %mor:\tco|well beg|beg adv|here pro:sub|I v|get pro:per|it .\n ",
#             "gra": " %gra:\t1|0|BEG 2|1|BEGP 3|5|JCT 4|5|SUBJ 5|0|ROOT 6|5|OBJ 7|5|PUNCT\n  %gra:\t1|0|BEG 2|1|BEGP 3|5|JCT 4|5|SUBJ 5|0|ROOT 6|5|OBJ 7|5|PUNCT\n ",
#             "wor": " %wor:\t+\" &=ges well \u001584820_84910\u0015 \u2021 here \u001584910_85200\u0015 I \u001585200_85340\u0015 get \u001585340_85550\u0015 it \u001585550_85630\u0015 .\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\t+\" I don't need it . \u001586351_87041\u0015\n ",
#             "mor": " %mor:\tpro:sub|I mod|do~neg|not v|need pro:per|it .\n  %mor:\tpro:sub|I mod|do~neg|not v|need pro:per|it .\n ",
#             "gra": " %gra:\t1|4|SUBJ 2|4|AUX 3|2|NEG 4|0|ROOT 5|4|OBJ 6|4|PUNCT\n  %gra:\t1|4|SUBJ 2|4|AUX 3|2|NEG 4|0|ROOT 5|4|OBJ 6|4|PUNCT\n ",
#             "wor": " %wor:\t+\" I \u001586351_86441\u0015 don't \u001586441_86651\u0015 need \u001586651_86901\u0015 it \u001586901_87041\u0015 .\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\t+\" &=points:picture_three &=ges oh . \u001587943_88093\u0015\n ",
#             "mor": " %mor:\tco|oh .\n  %mor:\tco|oh .\n ",
#             "gra": " %gra:\t1|0|INCROOT 2|1|PUNCT\n  %gra:\t1|0|INCROOT 2|1|PUNCT\n ",
#             "wor": " %wor:\t+\" &=points:picture_three &=ges oh \u001587943_88093\u0015 .\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\the said +\"/. \u001588108_88378\u0015\n ",
#             "mor": " %mor:\tpro:sub|he v|say&PAST +\"/.\n  %mor:\tpro:sub|he v|say&PAST +\"/.\n ",
#             "gra": " %gra:\t1|2|SUBJ 2|0|ROOT 3|2|PUNCT\n  %gra:\t1|2|SUBJ 2|0|ROOT 3|2|PUNCT\n ",
#             "wor": " %wor:\the \u001588108_88218\u0015 said \u001588218_88378\u0015 +\"/.\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\t+\" &=ges:cover I got a k\u0254du@u [: x@n] [* n:uk] . [+ jar] \u001588556_89446\u0015\n ",
#             "mor": " %mor:\tpro:sub|I v|get&PAST det:art|a neo|x .\n  %mor:\tpro:sub|I v|get&PAST det:art|a neo|x .\n ",
#             "gra": " %gra:\t1|2|SUBJ 2|0|ROOT 3|4|DET 4|2|OBJ 5|2|PUNCT\n  %gra:\t1|2|SUBJ 2|0|ROOT 3|4|DET 4|2|OBJ 5|2|PUNCT\n ",
#             "wor": " %wor:\t+\" &=ges:cover I \u001588556_88656\u0015 got \u001588656_89136\u0015 a \u001589136_89436\u0015 k\u0254du@u [: x@n] [* n:uk] \u001589436_89446\u0015 . [+ jar]\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\t+\" &=ges oh \u2021 I got a_lot_of xxx . [+ jar] \u001590181_91651\u0015\n ",
#             "mor": " %mor:\tco|oh beg|beg pro:sub|I v|get&PAST qn|a_lot_of .\n  %mor:\tco|oh beg|beg pro:sub|I v|get&PAST qn|a_lot_of .\n ",
#             "gra": " %gra:\t1|0|BEG 2|1|BEGP 3|4|SUBJ 4|0|ROOT 5|4|OBJ 6|4|PUNCT\n  %gra:\t1|0|BEG 2|1|BEGP 3|4|SUBJ 4|0|ROOT 5|4|OBJ 6|4|PUNCT\n ",
#             "wor": " %wor:\t+\" &=ges oh \u001590181_90521\u0015 \u2021 I \u001590521_90551\u0015 got \u001590551_90731\u0015 a_lot_of \u001590731_91651\u0015 xxx . [+ jar]\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\t+\" I got xxx &=points:picture_four . [+ jar] \u001592460_92560\u0015\n ",
#             "mor": " %mor:\tpro:sub|I v|get&PAST .\n  %mor:\tpro:sub|I v|get&PAST .\n ",
#             "gra": " %gra:\t1|2|SUBJ 2|0|ROOT 3|2|PUNCT\n  %gra:\t1|2|SUBJ 2|0|ROOT 3|2|PUNCT\n ",
#             "wor": " %wor:\t+\" I \u001592460_92470\u0015 got \u001592470_92560\u0015 xxx &=points:picture_four . [+ jar]\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\t&=points:picture_five and he went back . \u001592580_93510\u0015\n ",
#             "mor": " %mor:\tcoord|and pro:sub|he v|go&PAST adv|back .\n  %mor:\tcoord|and pro:sub|he v|go&PAST adv|back .\n ",
#             "gra": " %gra:\t1|3|LINK 2|3|SUBJ 3|0|ROOT 4|3|JCT 5|3|PUNCT\n  %gra:\t1|3|LINK 2|3|SUBJ 3|0|ROOT 4|3|JCT 5|3|PUNCT\n ",
#             "wor": " %wor:\t&=points:picture_five and \u001592580_92670\u0015 he \u001592750_92900\u0015 went \u001592940_93260\u0015 back \u001593260_93510\u0015 .\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\tand she's mad &=ges:anger . \u001594218_95098\u0015\n ",
#             "mor": " %mor:\tcoord|and pro:sub|she~cop|be&3S adj|mad .\n  %mor:\tcoord|and pro:sub|she~cop|be&3S adj|mad .\n ",
#             "gra": " %gra:\t1|3|LINK 2|3|SUBJ 3|0|ROOT 4|3|PRED 5|3|PUNCT\n  %gra:\t1|3|LINK 2|3|SUBJ 3|0|ROOT 4|3|PRED 5|3|PUNCT\n ",
#             "wor": " %wor:\tand \u001594218_94408\u0015 she's \u001594408_94758\u0015 mad \u001594758_95098\u0015 &=ges:anger .\n  \n "
#         },
#         {
#             "speaker": "INV",
#             "gra": "*INV:\t&=laughs .\n  %wor:\t&=laughs .\n  \n *INV:\t&=laughs .\n  %wor:\t&=laughs .\n  \n *INV:\t&=laughs .\n ",
#             "wor": " %wor:\t&=laughs .\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\tand <she said> [//] she says +\"/. \u001595919_97289\u0015\n ",
#             "mor": " %mor:\tcoord|and pro:sub|she v|say-3S +\"/.\n  %mor:\tcoord|and pro:sub|she v|say-3S +\"/.\n ",
#             "gra": " %gra:\t1|3|LINK 2|3|SUBJ 3|0|ROOT 4|3|PUNCT\n  %gra:\t1|3|LINK 2|3|SUBJ 3|0|ROOT 4|3|PUNCT\n ",
#             "wor": " %wor:\tand \u001595919_96499\u0015 <she \u001596529_96559\u0015 said \u001596559_96879\u0015> [//] she says +\"/. \u001597049_97289\u0015\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\t+\" &=points:picture_five oh \u2021 look at him . \u001597755_98475\u0015\n ",
#             "mor": " %mor:\tco|oh beg|beg v|look prep|at pro:obj|him .\n  %mor:\tco|oh beg|beg v|look prep|at pro:obj|him .\n ",
#             "gra": " %gra:\t1|0|BEG 2|1|BEGP 3|0|ROOT 4|3|JCT 5|4|POBJ 6|3|PUNCT\n  %gra:\t1|0|BEG 2|1|BEGP 3|0|ROOT 4|3|JCT 5|4|POBJ 6|3|PUNCT\n ",
#             "wor": " %wor:\t+\" &=points:picture_five oh \u001597755_97785\u0015 \u2021 look \u001597785_98135\u0015 at \u001598135_98285\u0015 him \u001598285_98475\u0015 .\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\t+\" it's bad . \u001598579_99019\u0015\n ",
#             "mor": " %mor:\tpro:per|it~cop|be&3S adj|bad .\n  %mor:\tpro:per|it~cop|be&3S adj|bad .\n ",
#             "gra": " %gra:\t1|2|SUBJ 2|0|ROOT 3|2|PRED 4|2|PUNCT\n  %gra:\t1|2|SUBJ 2|0|ROOT 3|2|PRED 4|2|PUNCT\n ",
#             "wor": " %wor:\t+\" it's \u001598579_98669\u0015 bad \u001598669_99019\u0015 .\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\tand he puts \u028ct [: up] [* p:n] &=ges:umbrella his cat [: umbrella]\n  \t[* s:ur] . \u001599517_100717\u0015\n ",
#             "mor": " %mor:\tcoord|and pro:sub|he v|put-3S prep|up det:poss|his n|umbrella .\n  %mor:\tcoord|and pro:sub|he v|put-3S prep|up det:poss|his n|umbrella .\n ",
#             "gra": " %gra:\t1|3|LINK 2|3|SUBJ 3|0|ROOT 4|3|JCT 5|6|DET 6|4|POBJ 7|3|PUNCT\n  %gra:\t1|3|LINK 2|3|SUBJ 3|0|ROOT 4|3|JCT 5|6|DET 6|4|POBJ 7|3|PUNCT\n ",
#             "wor": " %wor:\tand \u001599517_99617\u0015 he \u001599617_99747\u0015 puts \u001599807_100037\u0015 \u028ct [: up] [* p:n] \u0015100037_100237\u0015 &=ges:umbrella his \u0015100237_100427\u0015 cat [: umbrella]  [* s:ur] \u0015100457_100717\u0015 .\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\t&=ges:umbrella and he &=points:picture_six puts up with that .\n  \t[+ es] \u0015100848_101938\u0015\n ",
#             "mor": " %mor:\tcoord|and pro:sub|he v|put-3S adv|up prep|with pro:dem|that .\n  %mor:\tcoord|and pro:sub|he v|put-3S adv|up prep|with pro:dem|that .\n ",
#             "gra": " %gra:\t1|3|LINK 2|3|SUBJ 3|0|ROOT 4|3|JCT 5|3|JCT 6|5|POBJ 7|3|PUNCT\n  %gra:\t1|3|LINK 2|3|SUBJ 3|0|ROOT 4|3|JCT 5|3|JCT 6|5|POBJ 7|3|PUNCT\n ",
#             "wor": " %wor:\t&=ges:umbrella and \u0015100848_100998\u0015 he \u0015100998_101038\u0015 &=points:picture_six puts \u0015101038_101358\u0015 up \u0015101358_101558\u0015 with \u0015101558_101728\u0015 that \u0015101728_101938\u0015 .  [+ es]\n  \n "
#         },
#         {
#             "speaker": "INV",
#             "dialogue": "*INV:\tmhm . \u0015102528_102888\u0015\n ",
#             "mor": " %mor:\tco|mhm=yes .\n  %mor:\tco|mhm=yes .\n ",
#             "gra": " %gra:\t1|0|INCROOT 2|1|PUNCT\n  %gra:\t1|0|INCROOT 2|1|PUNCT\n ",
#             "wor": " %wor:\tmhm \u0015102528_102888\u0015 .\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\tgood . [+ exc] \u0015103055_103285\u0015\n ",
#             "mor": " %mor:\tadj|good .\n  %mor:\tadj|good .\n ",
#             "gra": " %gra:\t1|0|INCROOT 2|1|PUNCT\n  %gra:\t1|0|INCROOT 2|1|PUNCT\n ",
#             "wor": " %wor:\tgood \u0015103055_103285\u0015 . [+ exc]\n  \n "
#         },
#         {
#             "speaker": "INV",
#             "dialogue": "*INV:\tyep . \u0015103493_103763\u0015\n ",
#             "mor": " %mor:\tco|yep .\n  %mor:\tco|yep .\n ",
#             "gra": " %gra:\t1|0|INCROOT 2|1|PUNCT\n  %gra:\t1|0|INCROOT 2|1|PUNCT\n ",
#             "wor": " %wor:\tyep \u0015103493_103763\u0015 .\n  \n "
#         },
#         {
#             "speaker": "INV",
#             "dialogue": "*INV:\tvery good . \u0015104124_104594\u0015\n ",
#             "mor": " %mor:\tadv|very adj|good .\n  %mor:\tadv|very adj|good .\n ",
#             "gra": " %gra:\t1|2|JCT 2|0|INCROOT 3|2|PUNCT\n  %gra:\t1|2|JCT 2|0|INCROOT 3|2|PUNCT\n ",
#             "wor": " %wor:\tvery \u0015104124_104364\u0015 good \u0015104364_104594\u0015 .\n  \n "
#         },
#         {
#             "speaker": "INV",
#             "dialogue": "*INV:\tI agree . \u0015104609_105239\u0015\n ",
#             "mor": " %mor:\tpro:sub|I v|agree .\n  %mor:\tpro:sub|I v|agree .\n ",
#             "gra": " %gra:\t1|2|SUBJ 2|0|ROOT 3|2|PUNCT\n  %gra:\t1|2|SUBJ 2|0|ROOT 3|2|PUNCT\n ",
#             "wor": " %wor:\tI \u0015104609_104689\u0015 agree \u0015104689_105239\u0015 .\n  @G:\tCat\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\toh . [+ exc] \u0015107376_107406\u0015\n ",
#             "mor": " %mor:\tco|oh .\n  %mor:\tco|oh .\n ",
#             "gra": " %gra:\t1|0|INCROOT 2|1|PUNCT\n  %gra:\t1|0|INCROOT 2|1|PUNCT\n ",
#             "wor": " %wor:\toh \u0015107376_107406\u0015 . [+ exc]\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\tmess I don't +/. [+ exc] \u0015114144_114854\u0015\n ",
#             "mor": " %mor:\tn|mess pro:sub|I mod|do~neg|not +/.\n  %mor:\tn|mess pro:sub|I mod|do~neg|not +/.\n ",
#             "gra": " %gra:\t1|0|INCROOT 2|5|SUBJ 3|5|AUX 4|3|NEG 5|1|PUNCT\n  %gra:\t1|0|INCROOT 2|5|SUBJ 3|5|AUX 4|3|NEG 5|1|PUNCT\n ",
#             "wor": " %wor:\tmess \u0015114144_114624\u0015 I \u0015114624_114634\u0015 don't \u0015114634_114854\u0015 +/. [+ exc]\n  \n "
#         },
#         {
#             "speaker": "INV",
#             "dialogue": "*INV:\t+< now here's a story +/. \u0015114635_115204\u0015\n ",
#             "mor": " %mor:\tadv:tem|now pro:exist|here~cop|be&3S det:art|a n|story +/.\n  %mor:\tadv:tem|now pro:exist|here~cop|be&3S det:art|a n|story +/.\n ",
#             "gra": " %gra:\t1|3|JCT 2|3|SUBJ 3|0|ROOT 4|5|DET 5|3|PRED 6|3|PUNCT\n  %gra:\t1|3|JCT 2|3|SUBJ 3|0|ROOT 4|5|DET 5|3|PRED 6|3|PUNCT\n ",
#             "wor": " %wor:\t+< now \u0015114034_114094\u0015 here's \u0015114094_114394\u0015 a \u0015114394_114444\u0015 story \u0015114444_115204\u0015 +/.\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\tmy goodness . [+ exc] \u0015115413_115953\u0015\n ",
#             "mor": " %mor:\tdet:poss|my co|goodness .\n  %mor:\tdet:poss|my co|goodness .\n ",
#             "gra": " %gra:\t1|2|DET 2|0|INCROOT 3|2|PUNCT\n  %gra:\t1|2|DET 2|0|INCROOT 3|2|PUNCT\n ",
#             "wor": " %wor:\tmy \u0015115413_115533\u0015 goodness \u0015115533_115953\u0015 . [+ exc]\n  \n "
#         },
#         {
#             "speaker": "INV",
#             "dialogue": "*INV:\t+, called Cat_Rescue . \u0015115819_117509\u0015\n ",
#             "mor": " %mor:\tpart|call-PASTP n:prop|Cat_Rescue .\n  %mor:\tpart|call-PASTP n:prop|Cat_Rescue .\n ",
#             "gra": " %gra:\t1|0|INCROOT 2|1|OBJ 3|1|PUNCT\n  %gra:\t1|0|INCROOT 2|1|OBJ 3|1|PUNCT\n ",
#             "wor": " %wor:\t+, called \u0015115819_116159\u0015 Cat_Rescue \u0015116279_117509\u0015 .\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\the doesn't want &na neither one xxx . [+ esc] \u0015119192_120952\u0015\n ",
#             "mor": " %mor:\tpro:sub|he mod|do&3S~neg|not v|want qn|neither pro:indef|one .\n  %mor:\tpro:sub|he mod|do&3S~neg|not v|want qn|neither pro:indef|one .\n ",
#             "gra": " %gra:\t1|4|SUBJ 2|4|AUX 3|2|NEG 4|0|ROOT 5|6|QUANT 6|4|OBJ 7|4|PUNCT\n  %gra:\t1|4|SUBJ 2|4|AUX 3|2|NEG 4|0|ROOT 5|6|QUANT 6|4|OBJ 7|4|PUNCT\n ",
#             "wor": " %wor:\the \u0015119192_119252\u0015 doesn't \u0015119252_119652\u0015 want \u0015119652_120172\u0015 &na neither \u0015120172_120452\u0015 one \u0015120452_120952\u0015 xxx . [+ esc]\n  \n "
#         },
#         {
#             "speaker": "INV",
#             "dialogue": "*INV:\tand you tell us <a story:> [//] this story . \u0015121890_124790\u0015\n ",
#             "mor": " %mor:\tcoord|and pro:per|you v|tell pro:obj|us det:dem|this n|story .\n  %mor:\tcoord|and pro:per|you v|tell pro:obj|us det:dem|this n|story .\n ",
#             "gra": " %gra:\t1|3|LINK 2|3|SUBJ 3|0|ROOT 4|3|OBJ 5|6|DET 6|3|OBJ 7|3|PUNCT\n  %gra:\t1|3|LINK 2|3|SUBJ 3|0|ROOT 4|3|OBJ 5|6|DET 6|3|OBJ 7|3|PUNCT\n ",
#             "wor": " %wor:\tand \u0015121890_122060\u0015 you \u0015122060_122140\u0015 tell \u0015122140_122450\u0015 us \u0015122450_122630\u0015 <a \u0015122630_122670\u0015 story: \u0015122670_123760\u0015> [//] this story . \u0015124000_124790\u0015\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\twell \u2021 <he lets> [//] &=points:picture_cat he has some on . [+ es]\n  \t\u0015126638_128818\u0015\n ",
#             "mor": " %mor:\tco|well beg|beg pro:sub|he v|have&3S qn|some adv|on .\n  %mor:\tco|well beg|beg pro:sub|he v|have&3S qn|some adv|on .\n ",
#             "gra": " %gra:\t1|0|BEG 2|1|BEGP 3|4|SUBJ 4|0|ROOT 5|6|QUANT 6|4|JCT 7|4|PUNCT\n  %gra:\t1|0|BEG 2|1|BEGP 3|4|SUBJ 4|0|ROOT 5|6|QUANT 6|4|JCT 7|4|PUNCT\n ",
#             "wor": " %wor:\twell \u0015126638_127098\u0015 \u2021 <he \u0015127608_127638\u0015 lets \u0015127638_127788\u0015> [//] &=points:picture_cat he has some on . [+ es] \u0015127988_128818\u0015\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\tand she said +\"/. \u0015128836_129377\u0015\n ",
#             "mor": " %mor:\tcoord|and pro:sub|she v|say&PAST +\"/.\n  %mor:\tcoord|and pro:sub|she v|say&PAST +\"/.\n ",
#             "gra": " %gra:\t1|3|LINK 2|3|SUBJ 3|0|ROOT 4|3|PUNCT\n  %gra:\t1|3|LINK 2|3|SUBJ 3|0|ROOT 4|3|PUNCT\n ",
#             "wor": " %wor:\tand \u0015128837_129147\u0015 she \u0015129147_129157\u0015 said \u0015129157_129377\u0015 +\"/.\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\t+\" &=ges:reach I want him out but I don't get it . \u0015129743_131343\u0015\n ",
#             "mor": " %mor:\tpro:sub|I v|want pro:obj|him adv|out conj|but pro:sub|I\n  %mor:\tpro:sub|I v|want pro:obj|him adv|out conj|but pro:sub|I\n  \tmod|do~neg|not v|get pro:per|it .\n ",
#             "gra": " %gra:\t1|2|SUBJ 2|0|ROOT 3|2|OBJ 4|2|JCT 5|9|LINK 6|9|SUBJ 7|9|AUX 8|7|NEG\n  %gra:\t1|2|SUBJ 2|0|ROOT 3|2|OBJ 4|2|JCT 5|9|LINK 6|9|SUBJ 7|9|AUX 8|7|NEG\n  \t9|2|CJCT 10|9|OBJ 11|2|PUNCT\n ",
#             "wor": " %wor:\t+\" &=ges:reach I \u0015129743_129793\u0015 want \u0015129793_130183\u0015 him \u0015130183_130303\u0015 out \u0015130303_130443\u0015 but \u0015130443_130603\u0015 I \u0015130603_130793\u0015 don't \u0015130793_131043\u0015 get \u0015131043_131283\u0015 it \u0015131283_131343\u0015 .\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\t+\" &=ges:reach I don't get it there . \u0015131681_132671\u0015\n ",
#             "mor": " %mor:\tpro:sub|I mod|do~neg|not v|get pro:per|it adv|there .\n  %mor:\tpro:sub|I mod|do~neg|not v|get pro:per|it adv|there .\n ",
#             "gra": " %gra:\t1|4|SUBJ 2|4|AUX 3|2|NEG 4|0|ROOT 5|4|OBJ 6|4|JCT 7|4|PUNCT\n  %gra:\t1|4|SUBJ 2|4|AUX 3|2|NEG 4|0|ROOT 5|4|OBJ 6|4|JCT 7|4|PUNCT\n ",
#             "wor": " %wor:\t+\" &=ges:reach I \u0015131681_131761\u0015 don't \u0015131761_132031\u0015 get \u0015132031_132221\u0015 it \u0015132221_132411\u0015 there \u0015132411_132671\u0015 .\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\t&=points:picture_tree <she goes> [//] &=points:picture_man I hafta\n  \tgo xxx . \u0015132749_134239\u0015\n ",
#             "mor": " %mor:\tpro:sub|I mod|have~inf|to v|go .\n  %mor:\tpro:sub|I mod|have~inf|to v|go .\n ",
#             "gra": " %gra:\t1|4|SUBJ 2|4|AUX 3|4|INF 4|0|ROOT 5|4|PUNCT\n  %gra:\t1|4|SUBJ 2|4|AUX 3|4|INF 4|0|ROOT 5|4|PUNCT\n ",
#             "wor": " %wor:\t&=points:picture_tree <she \u0015132749_132759\u0015 goes \u0015133249_133509\u0015> [//] &=points:picture_man I hafta  go xxx . \u0015133509_134239\u0015\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\t&=points:picture_man he can't go up that &=points:picture_cat to\n  \tget him . [+ es] \u0015134461_136281\u0015\n ",
#             "mor": " %mor:\tpro:sub|he mod|can~neg|not v|go adv|up pro:dem|that inf|to v|get\n  %mor:\tpro:sub|he mod|can~neg|not v|go adv|up pro:dem|that inf|to v|get\n  \tpro:obj|him .\n ",
#             "gra": " %gra:\t1|4|SUBJ 2|4|AUX 3|2|NEG 4|0|ROOT 5|4|JCT 6|8|SUBJ 7|8|INF 8|4|XJCT\n  %gra:\t1|4|SUBJ 2|4|AUX 3|2|NEG 4|0|ROOT 5|4|JCT 6|8|SUBJ 7|8|INF 8|4|XJCT\n  \t9|8|OBJ 10|4|PUNCT\n ",
#             "wor": " %wor:\t&=points:picture_man he \u0015134461_134611\u0015 can't \u0015134641_134971\u0015 go \u0015134971_135131\u0015 up \u0015135131_135481\u0015 that \u0015135481_135601\u0015 &=points:picture_cat to \u0015135601_135701\u0015  get \u0015135911_136161\u0015 him \u0015136161_136281\u0015 . [+ es]\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\t&=points:picture_dog and <he can't> [/] &o &=points:picture_tree he\n  \tcan't hold [* s:uk] &=points:picture_man to get it &=laughs .\n  \t[+ jar] \u0015137352_139542\u0015\n ",
#             "mor": " %mor:\tcoord|and pro:sub|he mod|can~neg|not v|hold inf|to v|get pro:per|it\n  %mor:\tcoord|and pro:sub|he mod|can~neg|not v|hold inf|to v|get pro:per|it\n  \t.\n ",
#             "gra": " %gra:\t1|5|LINK 2|5|SUBJ 3|5|AUX 4|3|NEG 5|0|ROOT 6|7|INF 7|5|COMP 8|7|OBJ\n  %gra:\t1|5|LINK 2|5|SUBJ 3|5|AUX 4|3|NEG 5|0|ROOT 6|7|INF 7|5|COMP 8|7|OBJ\n  \t9|5|PUNCT\n ",
#             "wor": " %wor:\t&=points:picture_dog and \u0015137352_137532\u0015 <he \u0015137532_137762\u0015 can't \u0015137792_138322\u0015> [/] &o &=points:picture_tree he  can't hold [* s:uk] \u0015138402_139052\u0015 &=points:picture_man to \u0015139052_139112\u0015 get \u0015139112_139402\u0015 it \u0015139402_139542\u0015 &=laughs .  [+ jar]\n  \n "
#         },
#         {
#             "speaker": "INV",
#             "gra": "*INV:\t+< &=laughs .\n  %wor:\t+< &=laughs .\n  \n *INV:\t+< &=laughs .\n  %wor:\t+< &=laughs .\n  \n *INV:\t+< &=laughs .\n ",
#             "wor": " %wor:\t+< &=laughs .\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\t+< &=shrugs &=points:picture_girl so \u2021 he [/] he got . [+ es] \u0015141301_141821\u0015\n ",
#             "mor": " %mor:\tco|so beg|beg pro:sub|he v|get&PAST .\n  %mor:\tco|so beg|beg pro:sub|he v|get&PAST .\n ",
#             "gra": " %gra:\t1|0|BEG 2|1|BEGP 3|4|SUBJ 4|0|ROOT 5|4|PUNCT\n  %gra:\t1|0|BEG 2|1|BEGP 3|4|SUBJ 4|0|ROOT 5|4|PUNCT\n ",
#             "wor": " %wor:\t+< &=shrugs &=points:picture_girl so \u0015141301_141361\u0015 \u2021 he [/] \u0015141401_141411\u0015 he \u0015141411_141511\u0015 got \u0015141511_141821\u0015 . [+ es]\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\tlook at the &=points:picture_firemen . [+ exc] \u0015142198_142718\u0015\n ",
#             "mor": " %mor:\tv|look prep|at det:art|the .\n  %mor:\tv|look prep|at det:art|the .\n ",
#             "gra": " %gra:\t1|0|ROOT 2|1|JCT 3|2|POBJ 4|1|PUNCT\n  %gra:\t1|0|ROOT 2|1|JCT 3|2|POBJ 4|1|PUNCT\n ",
#             "wor": " %wor:\tlook \u0015142198_142418\u0015 at \u0015142418_142708\u0015 the \u0015142708_142718\u0015 &=points:picture_firemen . [+ exc]\n  \n "
#         },
#         {
#             "speaker": "INV",
#             "dialogue": "*INV:\t+< uhhuh . \u0015142709_142718\u0015\n ",
#             "mor": " %mor:\tco|uhhuh .\n  %mor:\tco|uhhuh .\n ",
#             "gra": " %gra:\t1|0|INCROOT 2|1|PUNCT\n  %gra:\t1|0|INCROOT 2|1|PUNCT\n ",
#             "wor": " %wor:\t+< uhhuh \u0015142678_142718\u0015 .\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\t&=points:picture_firemen &=points:picture_bird oh the &pa +//. \u0015144147_144527\u0015\n ",
#             "mor": " %mor:\tco|oh det:art|the +//.\n  %mor:\tco|oh det:art|the +//.\n ",
#             "gra": " %gra:\t1|0|INCROOT 2|3|DET 3|1|PUNCT\n  %gra:\t1|0|INCROOT 2|3|DET 3|1|PUNCT\n ",
#             "wor": " %wor:\t&=points:picture_firemen &=points:picture_bird oh \u0015144147_144367\u0015 the \u0015144477_144527\u0015 &pa +//.\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\twhat is it &=points:picture_firemen ? [+ exc] \u0015144600_145150\u0015\n ",
#             "mor": " %mor:\tpro:int|what cop|be&3S pro:per|it ?\n  %mor:\tpro:int|what cop|be&3S pro:per|it ?\n ",
#             "gra": " %gra:\t1|2|SUBJ 2|0|ROOT 3|2|PRED 4|2|PUNCT\n  %gra:\t1|2|SUBJ 2|0|ROOT 3|2|PRED 4|2|PUNCT\n ",
#             "wor": " %wor:\twhat \u0015144600_144880\u0015 is \u0015144880_144940\u0015 it \u0015145090_145150\u0015 &=points:picture_firemen ? [+ exc]\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\t&=laughs &=points:picture_bird this one xxx . [+ jar] \u0015147012_147552\u0015\n ",
#             "mor": " %mor:\tpro:dem|this pro:indef|one .\n  %mor:\tpro:dem|this pro:indef|one .\n ",
#             "gra": " %gra:\t1|2|SUBJ 2|0|INCROOT 3|2|PUNCT\n  %gra:\t1|2|SUBJ 2|0|INCROOT 3|2|PUNCT\n ",
#             "wor": " %wor:\t&=laughs &=points:picture_bird this \u0015147012_147202\u0015 one \u0015147202_147552\u0015 xxx . [+ jar]\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "gra": "*PAR:\t&=imit:bird &=laughs .\n  %wor:\t&=imit:bird &=laughs .\n  \n *PAR:\t&=imit:bird &=laughs .\n  %wor:\t&=imit:bird &=laughs .\n  \n *PAR:\t&=imit:bird &=laughs .\n ",
#             "wor": " %wor:\t&=imit:bird &=laughs .\n  \n "
#         },
#         {
#             "speaker": "INV",
#             "dialogue": "*INV:\tuhhuh . \u0015149122_149502\u0015\n ",
#             "mor": " %mor:\tco|uhhuh .\n  %mor:\tco|uhhuh .\n ",
#             "gra": " %gra:\t1|0|INCROOT 2|1|PUNCT\n  %gra:\t1|0|INCROOT 2|1|PUNCT\n ",
#             "wor": " %wor:\tuhhuh \u0015149122_149502\u0015 .\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\t&=points:picture_firemen assist him on the cat &=points:picture_dog\n  \t. [+ gram] \u0015149559_150519\u0015\n ",
#             "mor": " %mor:\tv|assist pro:obj|him prep|on det:art|the n|cat .\n  %mor:\tv|assist pro:obj|him prep|on det:art|the n|cat .\n ",
#             "gra": " %gra:\t1|0|ROOT 2|1|OBJ 3|1|JCT 4|5|DET 5|3|POBJ 6|1|PUNCT\n  %gra:\t1|0|ROOT 2|1|OBJ 3|1|JCT 4|5|DET 5|3|POBJ 6|1|PUNCT\n ",
# ...
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\t+< yeah nice . \u0015830539_831209\u0015\n ",
#             "mor": " %mor:\tco|yeah adj|nice .\n  %mor:\tco|yeah adj|nice .\n ",
#             "gra": " %gra:\t1|2|COM 2|0|INCROOT 3|2|PUNCT\n  %gra:\t1|2|COM 2|0|INCROOT 3|2|PUNCT\n ",
#             "wor": " %wor:\t+< yeah \u0015830539_830929\u0015 nice \u0015830929_831209\u0015 .\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "gra": "*PAR:\txxx . [+ jar]\n  %wor:\txxx . [+ jar]\n  \n *PAR:\txxx . [+ jar]\n  %wor:\txxx . [+ jar]\n  \n *PAR:\txxx . [+ jar]\n ",
#             "wor": " %wor:\txxx . [+ jar]\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\talright . \u0015832386_832596\u0015\n ",
#             "mor": " %mor:\tco|alright .\n  %mor:\tco|alright .\n ",
#             "gra": " %gra:\t1|0|INCROOT 2|1|PUNCT\n  %gra:\t1|0|INCROOT 2|1|PUNCT\n ",
#             "wor": " %wor:\talright \u0015832386_832596\u0015 .\n  \n "
#         },
#         {
#             "speaker": "INV",
#             "dialogue": "*INV:\tvery good . \u0015832679_833119\u0015\n ",
#             "mor": " %mor:\tadv|very adj|good .\n  %mor:\tadv|very adj|good .\n ",
#             "gra": " %gra:\t1|2|JCT 2|0|INCROOT 3|2|PUNCT\n  %gra:\t1|2|JCT 2|0|INCROOT 3|2|PUNCT\n ",
#             "wor": " %wor:\tvery \u0015832679_832919\u0015 good \u0015832919_833119\u0015 .\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\t+< use [//] you know &=ges where that new sky that went tw\u0251\u026ad@u\n  \t[: x@n] [* n:uk] . [+ jar] \u0015832920_835399\u0015\n ",
#             "mor": " %mor:\tpro:per|you v|know pro:int|where det:dem|that adj|new n|sky\n  %mor:\tpro:per|you v|know pro:int|where det:dem|that adj|new n|sky\n  \tpro:rel|that v|go&PAST neo|x .\n ",
#             "gra": " %gra:\t1|2|SUBJ 2|0|ROOT 3|6|LINK 4|6|DET 5|6|MOD 6|2|OBJ 7|8|LINK 8|6|CMOD\n  %gra:\t1|2|SUBJ 2|0|ROOT 3|6|LINK 4|6|DET 5|6|MOD 6|2|OBJ 7|8|LINK 8|6|CMOD\n  \t9|8|OBJ 10|2|PUNCT\n ",
#             "wor": " %wor:\t+< use [//] \u0015832909_833189\u0015 you \u0015833299_833389\u0015 know \u0015833389_833509\u0015 &=ges where \u0015833509_833629\u0015 that \u0015833629_833939\u0015 new \u0015833939_834189\u0015 sky \u0015834189_834349\u0015 that \u0015834349_834619\u0015 went \u0015834619_834879\u0015 tw\u0251\u026ad@u  [: x@n] [* n:uk] \u0015835369_835399\u0015 . [+ jar]\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\tand &-uh you put a &=ges:coat nice cold [* s:uk] . [+ jar] \u0015836257_837987\u0015\n ",
#             "mor": " %mor:\tcoord|and pro:per|you v|put&ZERO det:art|a adj|nice n|cold .\n  %mor:\tcoord|and pro:per|you v|put&ZERO det:art|a adj|nice n|cold .\n ",
#             "gra": " %gra:\t1|3|LINK 2|3|SUBJ 3|0|ROOT 4|6|DET 5|6|MOD 6|3|OBJ 7|3|PUNCT\n  %gra:\t1|3|LINK 2|3|SUBJ 3|0|ROOT 4|6|DET 5|6|MOD 6|3|OBJ 7|3|PUNCT\n ",
#             "wor": " %wor:\tand \u0015836257_836537\u0015 &-uh \u0015836847_836857\u0015 you \u0015836857_836927\u0015 put \u0015836987_837307\u0015 a \u0015837367_837397\u0015 &=ges:coat nice \u0015837397_837707\u0015 cold [* s:uk] \u0015837707_837987\u0015 . [+ jar]\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\t&=ges:coat I like all xxx . [+ jar] \u0015838123_839343\u0015\n ",
#             "mor": " %mor:\tpro:sub|I v|like adv|all .\n  %mor:\tpro:sub|I v|like adv|all .\n ",
#             "gra": " %gra:\t1|2|SUBJ 2|0|ROOT 3|2|JCT 4|2|PUNCT\n  %gra:\t1|2|SUBJ 2|0|ROOT 3|2|JCT 4|2|PUNCT\n ",
#             "wor": " %wor:\t&=ges:coat I \u0015838123_838213\u0015 like \u0015838213_838603\u0015 all \u0015838603_839343\u0015 xxx . [+ jar]\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\t&=shows:arms that's nice . [+ es] \u0015839519_840249\u0015\n ",
#             "mor": " %mor:\tpro:dem|that~cop|be&3S adj|nice .\n  %mor:\tpro:dem|that~cop|be&3S adj|nice .\n ",
#             "gra": " %gra:\t1|2|SUBJ 2|0|ROOT 3|2|PRED 4|2|PUNCT\n  %gra:\t1|2|SUBJ 2|0|ROOT 3|2|PRED 4|2|PUNCT\n ",
#             "wor": " %wor:\t&=shows:arms that's \u0015839519_839879\u0015 nice \u0015839879_840249\u0015 . [+ es]\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\t&=shows:arms nice k\u028cl@u [: x@n] [* n:uk] . [+ jar] \u0015841049_841379\u0015\n ",
#             "mor": " %mor:\tadj|nice neo|x .\n  %mor:\tadj|nice neo|x .\n ",
#             "gra": " %gra:\t1|2|MOD 2|0|INCROOT 3|2|PUNCT\n  %gra:\t1|2|MOD 2|0|INCROOT 3|2|PUNCT\n ",
#             "wor": " %wor:\t&=shows:arms nice \u0015841049_841279\u0015 k\u028cl@u [: x@n] [* n:uk] \u0015841279_841379\u0015 . [+ jar]\n  \n "
#         },
#         {
#             "speaker": "INV",
#             "dialogue": "*INV:\tmhm . \u0015841755_842085\u0015\n ",
#             "mor": " %mor:\tco|mhm=yes .\n  %mor:\tco|mhm=yes .\n ",
#             "gra": " %gra:\t1|0|INCROOT 2|1|PUNCT\n  %gra:\t1|0|INCROOT 2|1|PUNCT\n ",
#             "wor": " %wor:\tmhm \u0015841755_842085\u0015 .\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\t+< I have &=points:self that hole [* s:uk] when I get holts@u\n  \t[: x@n] [* n:uk] . \u0015841755_843495\u0015\n ",
#             "mor": " %mor:\tpro:sub|I v|have det:dem|that n|hole conj|when pro:sub|I v|get\n  %mor:\tpro:sub|I v|have det:dem|that n|hole conj|when pro:sub|I v|get\n  \tneo|x .\n ",
#             "gra": " %gra:\t1|2|SUBJ 2|0|ROOT 3|4|DET 4|2|OBJ 5|7|LINK 6|7|SUBJ 7|2|CJCT 8|7|OBJ\n  %gra:\t1|2|SUBJ 2|0|ROOT 3|4|DET 4|2|OBJ 5|7|LINK 6|7|SUBJ 7|2|CJCT 8|7|OBJ\n  \t9|2|PUNCT\n ",
#             "wor": " %wor:\t+< I \u0015841755_841865\u0015 have \u0015841865_842165\u0015 &=points:self that \u0015842165_842395\u0015 hole [* s:uk] \u0015842395_842545\u0015 when \u0015842545_842775\u0015 I \u0015842775_842885\u0015 get holts@u  [: x@n] [* n:uk] \u0015843445_843495\u0015 .\n  \n "
#         },
#         {
#             "speaker": "INV",
#             "dialogue": "*INV:\toh yeah . \u0015843570_844600\u0015\n ",
#             "mor": " %mor:\tco|oh co|yeah .\n  %mor:\tco|oh co|yeah .\n ",
#             "gra": " %gra:\t1|2|COM 2|0|INCROOT 3|2|PUNCT\n  %gra:\t1|2|COM 2|0|INCROOT 3|2|PUNCT\n ",
#             "wor": " %wor:\toh \u0015843570_844080\u0015 yeah \u0015844080_844600\u0015 .\n  \n "
#         },
#         {
#             "speaker": "INV",
#             "dialogue": "*INV:\tI've [/] I've have seen it . \u0015844717_846397\u0015\n ",
#             "mor": " %mor:\tpro:sub|I~aux|have aux|have part|see&PASTP pro:per|it .\n  %mor:\tpro:sub|I~aux|have aux|have part|see&PASTP pro:per|it .\n ",
#             "gra": " %gra:\t1|4|SUBJ 2|4|AUX 3|4|AUX 4|0|ROOT 5|4|OBJ 6|4|PUNCT\n  %gra:\t1|4|SUBJ 2|4|AUX 3|4|AUX 4|0|ROOT 5|4|OBJ 6|4|PUNCT\n ",
#             "wor": " %wor:\tI've [/] \u0015844717_845007\u0015 I've \u0015845197_845577\u0015 have \u0015845767_846037\u0015 seen \u0015846037_846327\u0015 it \u0015846327_846397\u0015 .\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\t+< yeah . \u0015846328_846329\u0015\n ",
#             "mor": " %mor:\tco|yeah .\n  %mor:\tco|yeah .\n ",
#             "gra": " %gra:\t1|0|INCROOT 2|1|PUNCT\n  %gra:\t1|0|INCROOT 2|1|PUNCT\n ",
#             "wor": " %wor:\t+< yeah \u0015846179_846259\u0015 .\n  \n "
#         },
#         {
#             "speaker": "INV",
#             "dialogue": "*INV:\tthat's right . \u0015846700_847120\u0015\n ",
#             "mor": " %mor:\tpro:dem|that~cop|be&3S co|right .\n  %mor:\tpro:dem|that~cop|be&3S co|right .\n ",
#             "gra": " %gra:\t1|2|SUBJ 2|0|ROOT 3|2|PRED 4|2|PUNCT\n  %gra:\t1|2|SUBJ 2|0|ROOT 3|2|PRED 4|2|PUNCT\n ",
#             "wor": " %wor:\tthat's \u0015846700_846910\u0015 right \u0015846910_847120\u0015 .\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\t+< yeah [/] yeah . \u0015846911_847500\u0015\n ",
#             "mor": " %mor:\tco|yeah .\n  %mor:\tco|yeah .\n ",
#             "gra": " %gra:\t1|0|INCROOT 2|1|PUNCT\n  %gra:\t1|0|INCROOT 2|1|PUNCT\n ",
#             "wor": " %wor:\t+< yeah [/] \u0015846840_847180\u0015 yeah \u0015847330_847500\u0015 .\n  \n "
#         },
#         {
#             "speaker": "INV",
#             "dialogue": "*INV:\t+< mhm . \u0015847365_847755\u0015\n ",
#             "mor": " %mor:\tco|mhm=yes .\n  %mor:\tco|mhm=yes .\n ",
#             "gra": " %gra:\t1|0|INCROOT 2|1|PUNCT\n  %gra:\t1|0|INCROOT 2|1|PUNCT\n ",
#             "wor": " %wor:\t+< mhm \u0015847365_847755\u0015 .\n  \n "
#         },
#         {
#             "speaker": "INV",
#             "dialogue": "*INV:\tyep . \u0015848531_848711\u0015\n ",
#             "mor": " %mor:\tco|yep .\n  %mor:\tco|yep .\n ",
#             "gra": " %gra:\t1|0|INCROOT 2|1|PUNCT\n  %gra:\t1|0|INCROOT 2|1|PUNCT\n ",
#             "wor": " %wor:\tyep \u0015848531_848711\u0015 .\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\t&=head:yes yeah . \u0015849160_849250\u0015\n ",
#             "mor": " %mor:\tco|yeah .\n  %mor:\tco|yeah .\n ",
#             "gra": " %gra:\t1|0|INCROOT 2|1|PUNCT\n  %gra:\t1|0|INCROOT 2|1|PUNCT\n ",
#             "wor": " %wor:\t&=head:yes yeah \u0015849160_849250\u0015 .\n  \n "
#         },
#         {
#             "speaker": "INV",
#             "dialogue": "*INV:\t+< so \u2021 it was a good trip . \u0015849230_850130\u0015\n ",
#             "mor": " %mor:\tco|so beg|beg pro:per|it cop|be&PAST&13S det:art|a adj|good n|trip\n  %mor:\tco|so beg|beg pro:per|it cop|be&PAST&13S det:art|a adj|good n|trip\n  \t.\n ",
#             "gra": " %gra:\t1|0|BEG 2|1|BEGP 3|4|SUBJ 4|0|ROOT 5|7|DET 6|7|MOD 7|4|PRED 8|4|PUNCT\n  %gra:\t1|0|BEG 2|1|BEGP 3|4|SUBJ 4|0|ROOT 5|7|DET 6|7|MOD 7|4|PRED 8|4|PUNCT\n ",
#             "wor": " %wor:\t+< so \u0015849230_849320\u0015 \u2021 it \u0015849320_849390\u0015 was \u0015849390_849530\u0015 a \u0015849530_849580\u0015 good \u0015849580_849810\u0015 trip \u0015849810_850130\u0015 .\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\tyep . \u0015850584_850704\u0015\n ",
#             "mor": " %mor:\tco|yep .\n  %mor:\tco|yep .\n ",
#             "gra": " %gra:\t1|0|INCROOT 2|1|PUNCT\n  %gra:\t1|0|INCROOT 2|1|PUNCT\n ",
#             "wor": " %wor:\tyep \u0015850584_850704\u0015 .\n  \n "
#         },
#         {
#             "speaker": "INV",
#             "dialogue": "*INV:\tI would love to follow in your footsteps . \u0015851780_853660\u0015\n ",
#             "mor": " %mor:\tpro:sub|I mod|will&COND v|love inf|to v|follow prep|in\n  %mor:\tpro:sub|I mod|will&COND v|love inf|to v|follow prep|in\n  \tdet:poss|your n|+n|foot+n|step-PL .\n ",
#             "gra": " %gra:\t1|3|SUBJ 2|3|AUX 3|0|ROOT 4|5|INF 5|3|COMP 6|5|JCT 7|8|DET 8|6|POBJ\n  %gra:\t1|3|SUBJ 2|3|AUX 3|0|ROOT 4|5|INF 5|3|COMP 6|5|JCT 7|8|DET 8|6|POBJ\n  \t9|3|PUNCT\n ",
#             "wor": " %wor:\tI \u0015851780_851870\u0015 would \u0015851870_852160\u0015 love \u0015852160_852350\u0015 to \u0015852350_852460\u0015 follow \u0015852550_852900\u0015 in \u0015852900_852990\u0015 your \u0015852990_853090\u0015 footsteps \u0015853090_853660\u0015 .\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\t+< I know . \u0015853899_854019\u0015\n ",
#             "mor": " %mor:\tpro:sub|I v|know .\n  %mor:\tpro:sub|I v|know .\n ",
#             "gra": " %gra:\t1|2|SUBJ 2|0|ROOT 3|2|PUNCT\n  %gra:\t1|2|SUBJ 2|0|ROOT 3|2|PUNCT\n ",
#             "wor": " %wor:\t+< I \u0015853899_853929\u0015 know \u0015853929_854019\u0015 .\n  \n "
#         },
#         {
#             "speaker": "INV",
#             "dialogue": "*INV:\tand go there myself . \u0015853930_855786\u0015\n ",
#             "mor": " %mor:\tcoord|and v|go adv|there pro:refl|myself .\n  %mor:\tcoord|and v|go adv|there pro:refl|myself .\n ",
#             "gra": " %gra:\t1|2|LINK 2|0|ROOT 3|2|JCT 4|2|JCT 5|2|PUNCT\n  %gra:\t1|2|LINK 2|0|ROOT 3|2|JCT 4|2|JCT 5|2|PUNCT\n ",
#             "wor": " %wor:\tand \u0015853676_854236\u0015 go \u0015854236_854766\u0015 there \u0015854766_855066\u0015 myself \u0015855066_855786\u0015 .\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\t+< I know you like to go there . \u0015855067_855608\u0015\n ",
#             "mor": " %mor:\tpro:sub|I v|know pro:per|you v|like inf|to v|go adv|there .\n  %mor:\tpro:sub|I v|know pro:per|you v|like inf|to v|go adv|there .\n ",
#             "gra": " %gra:\t1|2|SUBJ 2|0|ROOT 3|4|SUBJ 4|2|COMP 5|6|INF 6|4|COMP 7|6|JCT 8|2|PUNCT\n  %gra:\t1|2|SUBJ 2|0|ROOT 3|4|SUBJ 4|2|COMP 5|6|INF 6|4|COMP 7|6|JCT 8|2|PUNCT\n ",
#             "wor": " %wor:\t+< I \u0015854288_854548\u0015 know \u0015854548_854748\u0015 you \u0015854748_854808\u0015 like \u0015854808_855058\u0015 to \u0015855058_855188\u0015 go \u0015855188_855248\u0015 there \u0015855248_855608\u0015 .\n  \n "
#         },
#         {
#             "speaker": "INV",
#             "dialogue": "*INV:\t+< I tell you . \u0015855892_856542\u0015\n ",
#             "mor": " %mor:\tpro:sub|I v|tell pro:per|you .\n  %mor:\tpro:sub|I v|tell pro:per|you .\n ",
#             "gra": " %gra:\t1|2|SUBJ 2|0|ROOT 3|2|OBJ 4|2|PUNCT\n  %gra:\t1|2|SUBJ 2|0|ROOT 3|2|OBJ 4|2|PUNCT\n ",
#             "wor": " %wor:\t+< I \u0015855892_856042\u0015 tell \u0015856042_856332\u0015 you \u0015856332_856542\u0015 .\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\tI love to go . \u0015856806_857526\u0015\n ",
#             "mor": " %mor:\tpro:sub|I v|love inf|to v|go .\n  %mor:\tpro:sub|I v|love inf|to v|go .\n ",
#             "gra": " %gra:\t1|2|SUBJ 2|0|ROOT 3|4|INF 4|2|COMP 5|2|PUNCT\n  %gra:\t1|2|SUBJ 2|0|ROOT 3|4|INF 4|2|COMP 5|2|PUNCT\n ",
#             "wor": " %wor:\tI \u0015856806_856976\u0015 love \u0015856976_857226\u0015 to \u0015857226_857326\u0015 go \u0015857406_857526\u0015 .\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "dialogue": "*PAR:\t<I'd like to go in> [//] I'd like to go &=points next time . \u0015857941_860081\u0015\n ",
#             "mor": " %mor:\tpro:sub|I~mod|genmod v|like inf|to v|go adj|next n|time .\n  %mor:\tpro:sub|I~mod|genmod v|like inf|to v|go adj|next n|time .\n ",
#             "gra": " %gra:\t1|3|SUBJ 2|3|AUX 3|0|ROOT 4|5|INF 5|3|COMP 6|7|MOD 7|5|OBJ 8|3|PUNCT\n  %gra:\t1|3|SUBJ 2|3|AUX 3|0|ROOT 4|5|INF 5|3|COMP 6|7|MOD 7|5|OBJ 8|3|PUNCT\n ",
#             "wor": " %wor:\t<I'd \u0015857941_858111\u0015 like \u0015858111_858291\u0015 to \u0015858291_858401\u0015 go \u0015858401_858601\u0015 in \u0015858601_858711\u0015> [//] I'd like to go &=points next time . \u0015858801_860081\u0015\n  \n "
#         },
#         {
#             "speaker": "INV",
#             "dialogue": "*INV:\tyes &=laughs . \u0015860523_861773\u0015\n ",
#             "mor": " %mor:\tco|yes .\n  %mor:\tco|yes .\n ",
#             "gra": " %gra:\t1|0|INCROOT 2|1|PUNCT\n  %gra:\t1|0|INCROOT 2|1|PUNCT\n ",
#             "wor": " %wor:\tyes \u0015860523_861773\u0015 &=laughs .\n  \n "
#         },
#         {
#             "speaker": "PAR",
#             "gra": "*PAR:\t+< &=laughs .\n  %wor:\t+< &=laughs .\n  \n *PAR:\t+< &=laughs .\n  %wor:\t+< &=laughs .\n  \n *PAR:\t+< &=laughs .\n ",
#             "wor": " %wor:\t+< &=laughs .\n  \n "
#         },
#         {
#             "speaker": "INV",
#             "dialogue": "*INV:\tokay . \u0015863121_863881\u0015\n ",
#             "mor": " %mor:\tco|okay .\n  %mor:\tco|okay .\n ",
#             "gra": " %gra:\t1|0|INCROOT 2|1|PUNCT\n  %gra:\t1|0|INCROOT 2|1|PUNCT\n ",
#             "wor": " %wor:\tokay \u0015863121_863881\u0015 .\n  \n "
#         },
#         {
#             "speaker": "INV",
#             "gra": "*INV:\twww .\n  %wor:\twww .\n  %exp:\ttesting recorded, but not transcribed\n  @End\n  \n *INV:\twww .\n  %wor:\twww .\n  %exp:\ttesting recorded, but not transcribed\n  @End\n  \n *INV:\twww .\n ",
#             "wor": " %wor:\twww .\n  %exp:\ttesting recorded, but not transcribed\n  @End\n  \n "
#         }
#     ]
# }

# %%
# now use the above functions to store all files in the directory:

# dir_dict = {
#        "metadata": "<text from metadata file>",
#        "files": [
#            {
#                "filename": "<filename>",
#                "file": "<file dict>"
#            },
#            {
#                "filename": "<filename>",
#                "file": "<file dict>"
#            },
#            ...
#        ]
#    }

def Directory(dir):
    dir_dict = {}
    # iterate through all files in the directory
    # store all files in a list
    # store all file names in a list
    # store all file dicts in a list
    # store
    file_list = []
    file_name_list = []
    file_dict_list = []
    for file in os.listdir(dir):
        if file.endswith(".cha"):
            file_list.append(file)
            file_name_list.append(file)
            file_dict_list.append(Club(dir + "/" + file))
        
        if(file.endswith(".cdc")):
            with open(dir + "/" + file, 'r') as f:
                dir_dict["metadata"] = f.read()
        
    dir_dict["files"] = []
    for i in range(len(file_list)):
        dir_dict["files"].append({"filename": file_name_list[i], "file": file_dict_list[i]})
    
    return dir_dict

dir_dict = Directory('./English_Protocol_Aphasia/Garrett')

# print dir_dict in a formatted way
# print(json.dumps(dir_dict, indent=4))



# now use the above functions to store all directories in the directory_list:
Global_Dir_list = []
for dir in os.listdir('./English_Protocol_Aphasia'):
    Global_Dir_list.append(Directory('./English_Protocol_Aphasia/' + dir))

# print Global_Dir_list in a formatted way
print(json.dumps(Global_Dir_list, indent=4))
# Out:
# {
#     "metadata": "@UTF8\nCMDI_PID:\t11312/a-00032724-1\nTitle:\tAphasiaBank English Protocol PWA Garrett Corpus\nCreator:\tGarrett, Kathryn\nSubject:\taphasia\nSubject.olac:linguistic-field:\tneurolinguistics\nSubject.olac:language:\teng\nDescription:\t aphasic people engaged in AphasiaBank protocol\nPublisher:\tTalkBank\nContributor:\t\nDate:\t\t2013\nType:\tText\nType:\tSound\nType:\tmoving image\nType.olac:linguistic-type:\tprimary_text\nType.olac:discourse-type:\tdialogue\nIMDI_Genre:\tdiscourse\nIMDI_Interactivity:\tinteractive\nIMDI_PlanningType:\tspontaneous\nIMDI_Involvement:\tnon-elicited\nIMDI_SocialContext:\tfamily\nIMDI_EventStructure:\tconversation\nIMDI_Task:\tunspecified\nIMDI_Modalities:\tSpoken\nIMDI_Subject:\tunspecified\nIMDI_EthnicGroup:\tunspecified\nIMDI_RecordingConditions:\tunspecified\nIMDI_AccessAvailability:\topen access\nIMDI_Continent:\tNorth-America\nIMDI_Country:\tUnited States\nIMDI_ProjectDescription:\t\nIMDI_MediaFileDescription:\t\nIMDI_WrittenResourceSubType:\t\n\nDOI:\t10.21415/BPSP-YV25\n",
#     "files": [
#         {
#             "filename": "garrett02a.cha",
#             "file": {
#                 "metadata": "@UTF8\n @PID:\t11312/t-00017897-1\n @Begin\n @Languages:\teng\n @Participants:\tPAR garrett02a Participant, INV Investigator\n @Options:\tmulti\n @ID:\teng|Garrett|PAR|73;08.|male|Anomic||Participant||93.5|\n @ID:\teng|Garrett|INV|||||Investigator|||\n @Media:\tgarrett02a, video\n @Date:\t27-JUN-2011\n @Comment:\tthis participant has severe dysarthria and distorts many\n \tsounds, not all of which are captured in the transcription.\n @G:\tStroke\n ",
#                 "clubs": [
#                     {
#                         "speaker": "INV",
#                         "dialogue": "*INV:\ttell me about your stroke and how you're dealing with it . \u0015740_3780\u0015\n ",
#                         "mor": " %mor:\tv|tell pro:obj|me prep|about det:poss|your n|stroke coord|and\n  %mor:\tv|tell pro:obj|me prep|about det:poss|your n|stroke coord|and\n  \tpro:int|how pro:per|you~aux|be&PRES part|deal-PRESP prep|with\n  \tpro:per|it .\n ",
#                         "gra": " %gra:\t1|0|ROOT 2|1|OBJ 3|1|JCT 4|5|DET 5|3|POBJ 6|5|CONJ 7|10|LINK 8|10|SUBJ\n  %gra:\t1|0|ROOT 2|1|OBJ 3|1|JCT 4|5|DET 5|3|POBJ 6|5|CONJ 7|10|LINK 8|10|SUBJ\n  \t9|10|AUX 10|6|COORD 11|10|JCT 12|11|POBJ 13|1|PUNCT\n ",
#                         "wor": " %wor:\ttell \u0015740_950\u0015 me \u0015950_1120\u0015 about \u00151120_1430\u0015 your \u00151430_1550\u0015 stroke \u00151550_2350\u0015 and \u00152380_2590\u0015 how \u00152590_2710\u0015 you're \u00152710_2910\u0015 dealing \u00152910_3390\u0015 with \u00153390_3620\u0015 it \u00153620_3780\u0015 .\n  \n "
#                     },
#                     {
#                         "speaker": "PAR",
#                         "dialogue": "*PAR:\t&-um my stroke is the roughest thing I ever hadta do . \u00155266_13916\u0015\n ",
#                         "mor": " %mor:\tdet:poss|my n|stroke cop|be&3S det:art|the adj|rough-SP n|thing\n  %mor:\tdet:poss|my n|stroke cop|be&3S det:art|the adj|rough-SP n|thing\n  \tpro:sub|I adv|ever mod|have&PAST~inf|to v|do .\n ",
#                         "gra": " %gra:\t1|2|DET 2|3|SUBJ 3|0|ROOT 4|6|DET 5|6|MOD 6|3|PRED 7|11|SUBJ 8|11|JCT\n  %gra:\t1|2|DET 2|3|SUBJ 3|0|ROOT 4|6|DET 5|6|MOD 6|3|PRED 7|11|SUBJ 8|11|JCT\n  \t9|11|AUX 10|11|INF 11|6|CMOD 12|3|PUNCT\n ",
#                         "wor": " %wor:\t&-um \u00155266_5686\u0015 my \u00156196_6886\u0015 stroke \u00156886_7746\u0015 is \u00157896_8526\u0015 the \u00158526_8566\u0015 roughest \u00158596_10256\u0015 thing \u001510256_10696\u0015 I \u001511296_11686\u0015 ever \u001511736_12376\u0015 hadta \u001512616_13276\u0015 do \u001513276_13916\u0015 .\n  \n "
#                     },
#                     {
#                         "speaker": "PAR",
#                         "dialogue": "*PAR:\tit's an urge to talk walk (.) d\u0292uv@u [: move] [* p:n] my arm . \u001515135_21305\u0015\n ",
#                         "mor": " %mor:\tpro:per|it~cop|be&3S det:art|a n|urge prep|to n|talk n|walk n|move\n  %mor:\tpro:per|it~cop|be&3S det:art|a n|urge prep|to n|talk n|walk n|move\n  \tdet:poss|my n|arm .\n ",
#                         "gra": " %gra:\t1|2|SUBJ 2|0|ROOT 3|4|DET 4|2|PRED 5|4|NJCT 6|8|MOD 7|8|MOD 8|5|POBJ\n  %gra:\t1|2|SUBJ 2|0|ROOT 3|4|DET 4|2|PRED 5|4|NJCT 6|8|MOD 7|8|MOD 8|5|POBJ\n  \t9|10|DET 10|8|OBJ 11|2|PUNCT\n ",
#                         "wor": " %wor:\tit's \u001515135_15315\u0015 an \u001515385_15875\u0015 urge \u001515905_16515\u0015 to \u001516645_16725\u0015 talk \u001516725_17065\u0015 walk \u001517915_18315\u0015 (.) d\u0292uv@u [: move] [* p:n] \u001520035_20475\u0015 my \u001520475_20605\u0015 arm \u001520605_21305\u0015 .\n  \n "
#                     },
#                     {
#                         "speaker": "INV",
#                         "dialogue": "*INV:\tmhm . \u001521645_21815\u0015\n ",
#                         "mor": " %mor:\tco|mhm=yes .\n  %mor:\tco|mhm=yes .\n ",
#                         "gra": " %gra:\t1|0|INCROOT 2|1|PUNCT\n  %gra:\t1|0|INCROOT 2|1|PUNCT\n ",
#                         "wor": " %wor:\tmhm \u001521645_21815\u0015 .\n  \n "
#                     },
#                     {
#                         "speaker": "PAR",
#                         "dialogue": "*PAR:\tand &-uh &=shrugs I &d &-uh dealing with [/] &-uh with this one day\n  \tat a time . [+ gram] \u001523223_33893\u0015\n ",
#                         "mor": " %mor:\tcoord|and pro:sub|I part|deal-PRESP prep|with det:dem|this qn|one\n  %mor:\tcoord|and pro:sub|I part|deal-PRESP prep|with det:dem|this qn|one\n  \tn|day prep|at det:art|a n|time .\n ",
#                         "gra": " %gra:\t1|3|LINK 2|3|SUBJ 3|0|ROOT 4|3|JCT 5|7|DET 6|7|QUANT 7|4|POBJ 8|3|JCT\n  %gra:\t1|3|LINK 2|3|SUBJ 3|0|ROOT 4|3|JCT 5|7|DET 6|7|QUANT 7|4|POBJ 8|3|JCT\n  \t9|10|DET 10|8|POBJ 11|3|PUNCT\n ",
#                         "wor": " %wor:\tand \u001523223_23753\u0015 &-uh \u001525743_25753\u0015 &=shrugs I \u001525753_26073\u0015 &d &-uh \u001526463_26673\u0015 dealing \u001527943_28923\u0015 with [/] \u001528923_29763\u0015 &-uh \u001530333_30363\u0015 with \u001530363_30973\u0015 this \u001530973_31503\u0015 one \u001531723_32173\u0015 day \u001532173_32603\u0015  at \u001532603_32883\u0015 a \u001532883_33403\u0015 time \u001533443_33893\u0015 . [+ gram]\n  \n "
#                     },
#                     {
#                         "speaker": "INV",
#                         "dialogue": "*INV:\thow do you feel like you're coping with it ? \u001534256_38036\u0015\n ",
#                         "mor": " %mor:\tpro:int|how mod|do pro:per|you v|feel conj|like\n  %mor:\tpro:int|how mod|do pro:per|you v|feel conj|like\n  \tpro:per|you~aux|be&PRES part|cope-PRESP prep|with pro:per|it ?\n ",
#                         "gra": " %gra:\t1|4|LINK 2|4|AUX 3|4|SUBJ 4|0|ROOT 5|8|LINK 6|8|SUBJ 7|8|AUX 8|4|CJCT\n  %gra:\t1|4|LINK 2|4|AUX 3|4|SUBJ 4|0|ROOT 5|8|LINK 6|8|SUBJ 7|8|AUX 8|4|CJCT\n  \t9|8|JCT 10|9|POBJ 11|4|PUNCT\n ",
#                         "wor": " %wor:\thow \u001534256_35766\u0015 do \u001535766_35826\u0015 you \u001535826_35896\u0015 feel \u001535896_36246\u0015 like \u001536246_36576\u0015 you're \u001536576_37136\u0015 coping \u001537206_37606\u0015 with \u001537606_37846\u0015 it \u001537846_38036\u0015 ?\n  \n "
#                     },
#                     {
#                         "speaker": "PAR",
#                         "dialogue": "*PAR:\tpretty well . [+ gram] \u001539736_40736\u0015\n ",
#                         "mor": " %mor:\tadv|pretty adv|well .\n  %mor:\tadv|pretty adv|well .\n ",
#                         "gra": " %gra:\t1|2|JCT 2|0|INCROOT 3|2|PUNCT\n  %gra:\t1|2|JCT 2|0|INCROOT 3|2|PUNCT\n ",
#                         "wor": " %wor:\tpretty \u001539736_40266\u0015 well \u001540266_40736\u0015 . [+ gram]\n  \n "
#                     },
#                     {
#                         "speaker": "INV",
#                         "dialogue": "*INV:\tmhm . \u001541540_41720\u0015\n ",
#                         "mor": " %mor:\tco|mhm=yes .\n  %mor:\tco|mhm=yes .\n ",
#                         "gra": " %gra:\t1|0|INCROOT 2|1|PUNCT\n  %gra:\t1|0|INCROOT 2|1|PUNCT\n ",
#                         "wor": " %wor:\tmhm \u001541540_41720\u0015 .\n  \n "
#                     },
#                     {
#                         "speaker": "INV",
#                         "dialogue": "*INV:\tmhm \u2021 I'd say that's right . \u001543263_44683\u0015\n ",
#                         "mor": " %mor:\tco|mhm=yes beg|beg pro:sub|I~mod|genmod v|say comp|that~aux|be&3S\n  %mor:\tco|mhm=yes beg|beg pro:sub|I~mod|genmod v|say comp|that~aux|be&3S\n  \tco|right .\n ",
#                         "gra": " %gra:\t1|0|BEG 2|1|BEGP 3|5|SUBJ 4|5|AUX 5|0|ROOT 6|8|SUBJ 7|8|AUX 8|5|INCROOT\n  %gra:\t1|0|BEG 2|1|BEGP 3|5|SUBJ 4|5|AUX 5|0|ROOT 6|8|SUBJ 7|8|AUX 8|5|INCROOT\n  \t9|8|PUNCT\n ",
#                         "wor": " %wor:\tmhm \u001543263_43543\u0015 \u2021 I'd \u001543683_43843\u0015 say \u001543843_44083\u0015 that's \u001544083_44403\u0015 right \u001544403_44683\u0015 .\n  \n "
#                     },
#                     {
#                         "speaker": "INV",
#                         "dialogue": "*INV:\tI'd say that's right . \u001545603_46523\u0015\n ",
#                         "mor": " %mor:\tpro:sub|I~mod|genmod v|say comp|that~aux|be&3S co|right .\n  %mor:\tpro:sub|I~mod|genmod v|say comp|that~aux|be&3S co|right .\n ",
#                         "gra": " %gra:\t1|3|SUBJ 2|3|AUX 3|0|ROOT 4|6|SUBJ 5|6|AUX 6|3|INCROOT 7|6|PUNCT\n  %gra:\t1|3|SUBJ 2|3|AUX 3|0|ROOT 4|6|SUBJ 5|6|AUX 6|3|INCROOT 7|6|PUNCT\n ",
#                         "wor": " %wor:\tI'd \u001545603_45763\u0015 say \u001545763_45983\u0015 that's \u001545983_46273\u0015 right \u001546273_46523\u0015 .\n  \n "
#                     },
#                     {
#                         "speaker": "INV",
#                         "dialogue": "*INV:\tanything else you wanna tell me about it ? \u001549170_51160\u0015\n ",
#                         "mor": " %mor:\tpro:indef|anything post|else pro:per|you v|want~inf|to v|tell\n  %mor:\tpro:indef|anything post|else pro:per|you v|want~inf|to v|tell\n  \tpro:obj|me prep|about pro:per|it ?\n ",
#                         "gra": " %gra:\t1|4|LINK 2|1|PQ 3|4|SUBJ 4|0|ROOT 5|6|INF 6|4|COMP 7|6|OBJ 8|6|JCT\n  %gra:\t1|4|LINK 2|1|PQ 3|4|SUBJ 4|0|ROOT 5|6|INF 6|4|COMP 7|6|OBJ 8|6|JCT\n  \t9|8|POBJ 10|4|PUNCT\n ",
#                         "wor": " %wor:\tanything \u001549170_49610\u0015 else \u001549610_49850\u0015 you \u001549850_49920\u0015 wanna \u001549920_50150\u0015 tell \u001550150_50440\u0015 me \u001550440_50620\u0015 about \u001550620_50960\u0015 it \u001550960_51160\u0015 ?\n  \n "
#                     },
#                     {
#                         "speaker": "PAR",
#                         "dialogue": "*PAR:\tit sucks . \u001553181_54181\u0015\n ",
#                         "mor": " %mor:\tpro:per|it v|suck-3S .\n  %mor:\tpro:per|it v|suck-3S .\n ",
#                         "gra": " %gra:\t1|2|SUBJ 2|0|ROOT 3|2|PUNCT\n  %gra:\t1|2|SUBJ 2|0|ROOT 3|2|PUNCT\n ",
#                         "wor": " %wor:\tit \u001553181_53371\u0015 sucks \u001553371_54181\u0015 .\n  \n "
#                     },
#                     {
#                         "speaker": "INV",
#                         "dialogue": "*INV:\t&=laughs transcribe that . \u001554265_56245\u0015\n ",
#                         "mor": " %mor:\tv|transcribe pro:dem|that .\n  %mor:\tv|transcribe pro:dem|that .\n ",
#                         "gra": " %gra:\t1|0|ROOT 2|1|OBJ 3|1|PUNCT\n  %gra:\t1|0|ROOT 2|1|OBJ 3|1|PUNCT\n ",
#                         "wor": " %wor:\t&=laughs transcribe \u001554265_54995\u0015 that \u001554995_56245\u0015 .\n  \n "
#                     },
#                     {
#                         "speaker": "PAR",
#                         "gra": "*PAR:\t&=laughs .\n  %wor:\t&=laughs .\n  %com:\tthe video skips ahead .\n  @G:\tImportant_Event\n  \n *PAR:\t&=laughs .\n  %wor:\t&=laughs .\n  %com:\tthe video skips ahead .\n  @G:\tImportant_Event\n  \n *PAR:\t&=laughs .\n ",
#                         "wor": " %wor:\t&=laughs .\n  %com:\tthe video skips ahead .\n  @G:\tImportant_Event\n  \n "
#                     },
#                     {
#                         "speaker": "INV",
#                         "dialogue": "*INV:\tnow tell me about an important event that you +... \u001558528_62918\u0015\n ",
#                         "mor": " %mor:\tadv:tem|now v|tell pro:obj|me prep|about det:art|a adj|important\n  %mor:\tadv:tem|now v|tell pro:obj|me prep|about det:art|a adj|important\n  \tn|event pro:rel|that pro:per|you +...\n ",
#                         "gra": " %gra:\t1|2|SUBJ 2|0|ROOT 3|2|OBJ 4|2|JCT 5|7|DET 6|7|MOD 7|4|POBJ 8|9|LINK\n  %gra:\t1|2|SUBJ 2|0|ROOT 3|2|OBJ 4|2|JCT 5|7|DET 6|7|MOD 7|4|POBJ 8|9|LINK\n  \t9|7|CMOD 10|2|PUNCT\n ",
#                         "wor": " %wor:\tnow \u001558528_58818\u0015 tell \u001558818_59198\u0015 me \u001559198_59508\u0015 about \u001559508_60068\u0015 an \u001560068_60228\u0015 important \u001560228_60958\u0015 event \u001560958_61418\u0015 that \u001561758_62048\u0015 you \u001562048_62918\u0015 +...\n  \n "
#                     },
#                     {
#                         "speaker": "INV",
#                         "dialogue": "*INV:\t&-um I dunno could be something fun that you did in your life . \u001563616_68966\u0015\n ",
#                         "mor": " %mor:\tpro:sub|I mod|do~neg|no~v|know mod|could cop|be pro:indef|something\n  %mor:\tpro:sub|I mod|do~neg|no~v|know mod|could cop|be pro:indef|something\n  \tadj|fun comp|that pro:per|you v|do&PAST prep|in det:poss|your n|life\n  \t.\n ",
#                         "gra": " %gra:\t1|4|SUBJ 2|4|AUX 3|2|NEG 4|0|ROOT 5|6|AUX 6|4|COMP 7|6|PRED 8|7|PRED\n  %gra:\t1|4|SUBJ 2|4|AUX 3|2|NEG 4|0|ROOT 5|6|AUX 6|4|COMP 7|6|PRED 8|7|PRED\n  \t9|11|LINK 10|11|SUBJ 11|8|CMOD 12|11|JCT 13|14|DET 14|12|POBJ 15|4|PUNCT\n ",
#                         "wor": " %wor:\t&-um \u001563616_64176\u0015 I \u001564586_64676\u0015 dunno \u001564676_65096\u0015 could \u001565326_65466\u0015 be \u001565466_65556\u0015 something \u001565556_65926\u0015 fun \u001565926_66456\u0015 that \u001567056_67376\u0015 you \u001567376_67816\u0015 did \u001567816_68146\u0015 in \u001568146_68326\u0015 your \u001568326_68456\u0015 life \u001568456_68966\u0015 .\n  \n "
#                     },
#                     {
#                         "speaker": "INV",
#                         "dialogue": "*INV:\trecently or a long time ago, doesn't matter . \u001571533_74723\u0015\n ",
#                         "mor": " %mor:\tadv|recent&dadj-LY coord|or det:art|a adj|long n|time post|ago\n  %mor:\tadv|recent&dadj-LY coord|or det:art|a adj|long n|time post|ago\n  \tcm|cm mod|do&3S~neg|not v|matter .\n ",
#                         "gra": " %gra:\t1|10|JCT 2|1|CONJ 3|5|DET 4|5|MOD 5|2|COORD 6|5|POSTMOD 7|1|LP 8|10|AUX\n  %gra:\t1|10|JCT 2|1|CONJ 3|5|DET 4|5|MOD 5|2|COORD 6|5|POSTMOD 7|1|LP 8|10|AUX\n  \t9|8|NEG 10|0|ROOT 11|10|PUNCT\n ",
#                         "wor": " %wor:\trecently \u001571533_72633\u0015 or \u001572633_72803\u0015 a \u001572803_72843\u0015 long \u001572843_73113\u0015 time \u001573113_73423\u0015 ago, \u001573423_73923\u0015 doesn't \u001573953_74283\u0015 matter \u001574283_74723\u0015 .\n  \n "
#                     },
#                     {
#                         "speaker": "PAR",
#                         "dialogue": "*PAR:\tw:ent to &-um (.) hm: (.) hm: (.) so\u028a\u025blb\u026al\u026a\u014b@u [: snowmobiling]\n  \t[* n:k] . [+ gram] \u001577491_94131\u0015\n ",
#                         "mor": " %mor:\tv|go&PAST prep|to co|hm co|hm part|+n|snow+n|mobile-PRESP .\n  %mor:\tv|go&PAST prep|to co|hm co|hm part|+n|snow+n|mobile-PRESP .\n ",
#                         "gra": " %gra:\t1|0|ROOT 2|1|JCT 3|5|COM 4|5|COM 5|2|POBJ 6|1|PUNCT\n  %gra:\t1|0|ROOT 2|1|JCT 3|5|COM 4|5|COM 5|2|POBJ 6|1|PUNCT\n ",
#                         "wor": " %wor:\tw:ent \u001577491_78461\u0015 to \u001578461_79041\u0015 &-um \u001579801_80261\u0015 (.) hm: \u001580321_82131\u0015 (.) hm: \u001582171_87681\u0015 (.) so\u028a\u025blb\u026al\u026a\u014b@u [: snowmobiling]  [* n:k] \u001592111_94131\u0015 . [+ gram]\n  \n "
#                     },
#                     {
#                         "speaker": "INV",
#                         "dialogue": "*INV:\tthe sawmill building ? \u001597341_98571\u0015\n ",
#                         "mor": " %mor:\tdet:art|the n|+n|saw+n|mill n|building ?\n  %mor:\tdet:art|the n|+n|saw+n|mill n|building ?\n ",
#                         "gra": " %gra:\t1|3|DET 2|3|MOD 3|0|INCROOT 4|3|PUNCT\n  %gra:\t1|3|DET 2|3|MOD 3|0|INCROOT 4|3|PUNCT\n ",
#                         "wor": " %wor:\tthe \u001597341_97451\u0015 sawmill \u001597451_98031\u0015 building \u001598031_98571\u0015 ?\n  \n "
#                     },
#                     {
#                         "speaker": "PAR",
#                         "dialogue": "*PAR:\tno \u2021 so [: snow] [* p:w-rep] [/] so [: snow] [* p:w] +... \u001598916_102546\u0015\n ",
#                         "mor": " %mor:\tco|no beg|beg n|snow +...\n  %mor:\tco|no beg|beg n|snow +...\n ",
#                         "gra": " %gra:\t1|0|BEG 2|1|BEGP 3|0|INCROOT 4|3|PUNCT\n  %gra:\t1|0|BEG 2|1|BEGP 3|0|INCROOT 4|3|PUNCT\n ",
#                         "wor": " %wor:\tno \u001598916_99486\u0015 \u2021 so [: snow] [* p:w-rep] [/] \u0015100286_101086\u0015 so [: snow] [* p:w] \u0015101876_102546\u0015 +...\n  \n "
#                     },
#                     {
#                         "speaker": "INV",
#                         "dialogue": "*INV:\tsew ? \u0015102653_103303\u0015\n ",
#                         "mor": " %mor:\tv|sew ?\n  %mor:\tv|sew ?\n ",
#                         "gra": " %gra:\t1|0|ROOT 2|1|PUNCT\n  %gra:\t1|0|ROOT 2|1|PUNCT\n ",
#                         "wor": " %wor:\tsew \u0015102653_103303\u0015 ?\n  \n "
#                     },
#                     {
#                         "speaker": "PAR",
#                         "dialogue": "*PAR:\tno \u2021 so [: snow] [* p:w] . [+ gram] \u0015103553_104743\u0015\n ",
#                         "mor": " %mor:\tco|no beg|beg n|snow .\n  %mor:\tco|no beg|beg n|snow .\n ",
#                         "gra": " %gra:\t1|0|BEG 2|1|BEGP 3|0|INCROOT 4|3|PUNCT\n  %gra:\t1|0|BEG 2|1|BEGP 3|0|INCROOT 4|3|PUNCT\n ",
#                         "wor": " %wor:\tno \u0015103553_104073\u0015 \u2021 so [: snow] [* p:w] \u0015104073_104743\u0015 . [+ gram]\n  \n "
#                     },
#                     {
#                         "speaker": "PAR",
#                         "dialogue": "*PAR:\t&s &=flicks:hand white stuff . [+ gram] \u0015104991_106811\u0015\n ",
#                         "mor": " %mor:\tadj|white n|stuff .\n  %mor:\tadj|white n|stuff .\n ",
#                         "gra": " %gra:\t1|2|MOD 2|0|INCROOT 3|2|PUNCT\n  %gra:\t1|2|MOD 2|0|INCROOT 3|2|PUNCT\n ",
#                         "wor": " %wor:\t&s &=flicks:hand white \u0015104991_105141\u0015 stuff \u0015105141_106811\u0015 . [+ gram]\n  \n "
#                     },
#                     {
#                         "speaker": "PAR",
#                         "dialogue": "*PAR:\tno ? \u0015108213_108943\u0015\n ",
#                         "mor": " %mor:\tco|no ?\n  %mor:\tco|no ?\n ",
#                         "gra": " %gra:\t1|0|INCROOT 2|1|PUNCT\n  %gra:\t1|0|INCROOT 2|1|PUNCT\n ",
#                         "wor": " %wor:\tno \u0015108213_108943\u0015 ?\n  \n "
#                     },
#                     {
#                         "speaker": "INV",
#                         "dialogue": "*INV:\tyou went to a building . \u0015110893_112023\u0015\n ",
#                         "mor": " %mor:\tpro:per|you v|go&PAST prep|to det:art|a n|building .\n  %mor:\tpro:per|you v|go&PAST prep|to det:art|a n|building .\n ",
#                         "gra": " %gra:\t1|2|SUBJ 2|0|ROOT 3|2|JCT 4|5|DET 5|3|POBJ 6|2|PUNCT\n  %gra:\t1|2|SUBJ 2|0|ROOT 3|2|JCT 4|5|DET 5|3|POBJ 6|2|PUNCT\n ",
#                         "wor": " %wor:\tyou \u0015110893_111013\u0015 went \u0015111013_111213\u0015 to \u0015111213_111333\u0015 a \u0015111333_111393\u0015 building \u0015111393_112023\u0015 .\n  \n "
#                     },
#                     {
#                         "speaker": "PAR",
#                         "dialogue": "*PAR:\tno &=checks:fingernails . \u0015112276_112516\u0015\n ",
#                         "mor": " %mor:\tco|no .\n  %mor:\tco|no .\n ",
#                         "gra": " %gra:\t1|0|INCROOT 2|1|PUNCT\n  %gra:\t1|0|INCROOT 2|1|PUNCT\n ",
#                         "wor": " %wor:\tno \u0015112276_112516\u0015 &=checks:fingernails .\n  \n "
#                     },
#                     {
#                         "speaker": "PAR",
#                         "dialogue": "*PAR:\tso\u028a\u025blb\u026al\u026a\u014b@u [: snowmobiling] [* n:k] . [+ gram] \u0015114505_116665\u0015\n ",
#                         "mor": " %mor:\tpart|+n|snow+n|mobile-PRESP .\n  %mor:\tpart|+n|snow+n|mobile-PRESP .\n ",
#                         "gra": " %gra:\t1|0|INCROOT 2|1|PUNCT\n  %gra:\t1|0|INCROOT 2|1|PUNCT\n ",
#                         "wor": " %wor:\tso\u028a\u025blb\u026al\u026a\u014b@u [: snowmobiling] [* n:k] \u0015114505_116665\u0015 . [+ gram]\n  \n "
#                     },
#                     {
#                         "speaker": "INV",
#                         "dialogue": "*INV:\t\u0283:o\u028amo\u028a@u [: x@n] [* n:uk] ? \u0015120778_120808\u0015\n ",
#                         "mor": " %mor:\tneo|x ?\n  %mor:\tneo|x ?\n ",
#                         "gra": " %gra:\t1|0|INCROOT 2|1|PUNCT\n  %gra:\t1|0|INCROOT 2|1|PUNCT\n ",
#                         "wor": " %wor:\t\u0283:o\u028amo\u028a@u [: x@n] [* n:uk] \u0015120778_120808\u0015 ?\n  \n "
#                     },
#                     {
#                         "speaker": "PAR",
#                         "gra": "*PAR:\t&=laughs .\n  %wor:\t&=laughs .\n  \n *PAR:\t&=laughs .\n  %wor:\t&=laughs .\n  \n *PAR:\t&=laughs .\n ",
#                         "wor": " %wor:\t&=laughs .\n  \n "
#                     },
#                     {
#                         "speaker": "INV",
#                         "dialogue": "*INV:\t&c can you write it ? \u0015124910_127490\u0015\n ",
#                         "mor": " %mor:\tmod|can pro:per|you v|write pro:per|it ?\n  %mor:\tmod|can pro:per|you v|write pro:per|it ?\n ",
#                         "gra": " %gra:\t1|3|AUX 2|3|SUBJ 3|0|ROOT 4|3|OBJ 5|3|PUNCT\n  %gra:\t1|3|AUX 2|3|SUBJ 3|0|ROOT 4|3|OBJ 5|3|PUNCT\n ",
#                         "wor": " %wor:\t&c can \u0015124910_125560\u0015 you \u0015126790_127050\u0015 write \u0015127050_127280\u0015 it \u0015127280_127490\u0015 ?\n  \n "
#                     },
#                     {
#                         "speaker": "PAR",
#                         "dialogue": "*PAR:\tno \u2021 I went to &-uh &-uh (.) xxx &s &s +... \u0015127951_138791\u0015\n ",
#                         "mor": " %mor:\tco|no beg|beg pro:sub|I v|go&PAST prep|to +...\n  %mor:\tco|no beg|beg pro:sub|I v|go&PAST prep|to +...\n ",
#                         "gra": " %gra:\t1|0|BEG 2|1|BEGP 3|4|SUBJ 4|0|ROOT 5|4|JCT 6|4|PUNCT\n  %gra:\t1|0|BEG 2|1|BEGP 3|4|SUBJ 4|0|ROOT 5|4|JCT 6|4|PUNCT\n ",
#                         "wor": " %wor:\tno \u0015127951_128511\u0015 \u2021 I \u0015129571_129841\u0015 went \u0015129841_130501\u0015 to \u0015130501_131321\u0015 &-uh \u0015136581_137161\u0015 &-uh \u0015138331_138791\u0015 (.) xxx &s &s +...\n  \n "
#                     },
#                     {
#                         "speaker": "PAR",
#                         "dialogue": "*PAR:\tI went to the Grand_Canyon . \u0015143876_147246\u0015\n ",
#                         "mor": " %mor:\tpro:sub|I v|go&PAST prep|to det:art|the n:prop|Grand_Canyon .\n  %mor:\tpro:sub|I v|go&PAST prep|to det:art|the n:prop|Grand_Canyon .\n ",
#                         "gra": " %gra:\t1|2|SUBJ 2|0|ROOT 3|2|JCT 4|5|DET 5|3|POBJ 6|2|PUNCT\n  %gra:\t1|2|SUBJ 2|0|ROOT 3|2|JCT 4|5|DET 5|3|POBJ 6|2|PUNCT\n ",
#                         "wor": " %wor:\tI \u0015143876_144126\u0015 went \u0015144126_144676\u0015 to \u0015144676_144826\u0015 the \u0015144826_144836\u0015 Grand_Canyon \u0015144836_147246\u0015 .\n  \n "
#                     },
#                     {
#                         "speaker": "INV",
#                         "gra": "*INV:\t&=gasps .\n  %wor:\t&=gasps .\n  \n *INV:\t&=gasps .\n  %wor:\t&=gasps .\n  \n *INV:\t&=gasps .\n ",
#                         "wor": " %wor:\t&=gasps .\n  \n "
#                     },
#                     {
#                         "speaker": "PAR",
#                         "dialogue": "*PAR:\t<it was for> [//] &-uh it was (.) &n nice . \u0015148545_156725\u0015\n ",
#                         "mor": " %mor:\tpro:per|it cop|be&PAST&13S adj|nice .\n  %mor:\tpro:per|it cop|be&PAST&13S adj|nice .\n ",
#                         "gra": " %gra:\t1|2|SUBJ 2|0|ROOT 3|2|PRED 4|2|PUNCT\n  %gra:\t1|2|SUBJ 2|0|ROOT 3|2|PRED 4|2|PUNCT\n ",
#                         "wor": " %wor:\t<it \u0015148545_148795\u0015 was \u0015148795_149505\u0015 for \u0015149505_150215\u0015> [//] &-uh it was (.) &n nice . \u0015151545_156725\u0015\n  \n "
#                     },
#                     {
#                         "speaker": "PAR",
#                         "dialogue": "*PAR:\tand I went to the p\u025c\u02det\u0279\u0259fa\u026ad@u [: petrified] [* p:n] forest . \u0015157263_163293\u0015\n ",
#                         "mor": " %mor:\tcoord|and pro:sub|I v|go&PAST prep|to det:art|the\n  %mor:\tcoord|and pro:sub|I v|go&PAST prep|to det:art|the\n  \tpart|petrify-PASTP n|forest .\n ",
#                         "gra": " %gra:\t1|3|LINK 2|3|SUBJ 3|0|ROOT 4|3|JCT 5|7|DET 6|7|MOD 7|4|POBJ 8|3|PUNCT\n  %gra:\t1|3|LINK 2|3|SUBJ 3|0|ROOT 4|3|JCT 5|7|DET 6|7|MOD 7|4|POBJ 8|3|PUNCT\n ",
#                         "wor": " %wor:\tand \u0015157263_157773\u0015 I \u0015157773_158043\u0015 went \u0015158043_158773\u0015 to \u0015159493_159843\u0015 the \u0015160283_160303\u0015 p\u025c\u02det\u0279\u0259fa\u026ad@u [: petrified] [* p:n] \u0015160303_162023\u0015 forest \u0015162023_163293\u0015 .\n  \n "
#                     },
#                     {
#                         "speaker": "INV",
#                         "dialogue": "*INV:\tyep . \u0015166309_166419\u0015\n ",
#                         "mor": " %mor:\tco|yep .\n  %mor:\tco|yep .\n ",
#                         "gra": " %gra:\t1|0|INCROOT 2|1|PUNCT\n  %gra:\t1|0|INCROOT 2|1|PUNCT\n ",
#                         "wor": " %wor:\tyep \u0015166309_166419\u0015 .\n  \n "
#                     },
#                     {
#                         "speaker": "PAR",
#                         "dialogue": "*PAR:\tI &z went to see Old_Faithful . \u0015167493_171793\u0015\n ",
#                         "mor": " %mor:\tpro:sub|I v|go&PAST inf|to v|see n:prop|Old_Faithful .\n  %mor:\tpro:sub|I v|go&PAST inf|to v|see n:prop|Old_Faithful .\n ",
#                         "gra": " %gra:\t1|2|SUBJ 2|0|ROOT 3|4|INF 4|2|COMP 5|4|OBJ 6|2|PUNCT\n  %gra:\t1|2|SUBJ 2|0|ROOT 3|4|INF 4|2|COMP 5|4|OBJ 6|2|PUNCT\n ",
#                         "wor": " %wor:\tI \u0015167493_167813\u0015 &z went \u0015168493_168943\u0015 to \u0015168943_169473\u0015 see \u0015169473_170143\u0015 Old_Faithful \u0015170443_171793\u0015 .\n  \n "
#                     },
#                     {
#                         "speaker": "INV",
#                         "dialogue": "*INV:\tyou did the trip I did when I was twenty years old . \u0015172636_175346\u0015\n ",
#                         "mor": " %mor:\tpro:per|you v|do&PAST det:art|the n|trip pro:sub|I v|do&PAST\n  %mor:\tpro:per|you v|do&PAST det:art|the n|trip pro:sub|I v|do&PAST\n  \tconj|when pro:sub|I cop|be&PAST&13S det:num|twenty n|year-PL adj|old\n  \t.\n ",
#                         "gra": " %gra:\t1|2|SUBJ 2|6|CJCT 3|4|DET 4|2|OBJ 5|6|SUBJ 6|0|ROOT 7|9|LINK 8|9|SUBJ\n  %gra:\t1|2|SUBJ 2|6|CJCT 3|4|DET 4|2|OBJ 5|6|SUBJ 6|0|ROOT 7|9|LINK 8|9|SUBJ\n  \t9|6|CJCT 10|11|QUANT 11|12|MOD 12|9|PRED 13|6|PUNCT\n ",
#                         "wor": " %wor:\tyou \u0015172636_172716\u0015 did \u0015172716_172926\u0015 the \u0015172926_173016\u0015 trip \u0015173016_173316\u0015 I \u0015173316_173506\u0015 did \u0015173506_173786\u0015 when \u0015173786_173976\u0015 I \u0015173976_174106\u0015 was \u0015174106_174306\u0015 twenty \u0015174306_174736\u0015 years \u0015174736_175036\u0015 old \u0015175036_175346\u0015 .\n  \n "
#                     },
#                     {
#                         "speaker": "PAR",
#                         "dialogue": "*PAR:\tand &-uh I went &s so\u028a\u025blb\u026al\u026a\u014b@u [: snowmobiling] [* n:k] in &-uh\n  \t&-uh &-uh +... \u0015176051_185401\u0015\n ",
#                         "mor": " %mor:\tcoord|and pro:sub|I v|go&PAST part|+n|snow+n|mobile-PRESP adv|in\n  %mor:\tcoord|and pro:sub|I v|go&PAST part|+n|snow+n|mobile-PRESP adv|in\n  \t+...\n ",
#                         "gra": " %gra:\t1|3|LINK 2|3|SUBJ 3|4|SRL 4|0|ROOT 5|4|JCT 6|4|PUNCT\n  %gra:\t1|3|LINK 2|3|SUBJ 3|4|SRL 4|0|ROOT 5|4|JCT 6|4|PUNCT\n ",
#                         "wor": " %wor:\tand \u0015176051_176621\u0015 &-uh \u0015177641_177651\u0015 I \u0015177651_177911\u0015 went \u0015177941_178511\u0015 &s so\u028a\u025blb\u026al\u026a\u014b@u [: snowmobiling] [* n:k] \u0015179311_181831\u0015 in \u0015182011_182071\u0015 &-uh \u0015182331_183021\u0015  &-uh \u0015183881_184221\u0015 &-uh \u0015185011_185401\u0015 +...\n  \n "
#                     },
#                     {
#                         "speaker": "INV",
#                         "dialogue": "*INV:\tin +..? \u0015189395_190475\u0015\n ",
#                         "mor": " %mor:\tadv|in +..?\n  %mor:\tadv|in +..?\n ",
#                         "gra": " %gra:\t1|0|INCROOT 2|1|PUNCT\n  %gra:\t1|0|INCROOT 2|1|PUNCT\n ",
#                         "wor": " %wor:\tin \u0015189395_190475\u0015 +..?\n  \n "
#                     },
#                     {
#                         "speaker": "PAR",
#                         "dialogue": "*PAR:\t++ the park &-uh +... \u0015191015_193065\u0015\n ",
#                         "mor": " %mor:\tdet:art|the n|park +...\n  %mor:\tdet:art|the n|park +...\n ",
#                         "gra": " %gra:\t1|2|DET 2|0|INCROOT 3|2|PUNCT\n  %gra:\t1|2|DET 2|0|INCROOT 3|2|PUNCT\n ",
#                         "wor": " %wor:\t++ the \u0015191015_191245\u0015 park \u0015192115_192475\u0015 &-uh \u0015192715_193065\u0015 +...\n  \n "
#                     },
#                     {
#                         "speaker": "PAR",
#                         "dialogue": "*PAR:\tw:here's the grand xxx &-uh Old_Faithful ? \u0015194283_199263\u0015\n ",
#                         "mor": " %mor:\tpro:int|where~cop|be&3S det:art|the adj|grand n:prop|Old_Faithful ?\n  %mor:\tpro:int|where~cop|be&3S det:art|the adj|grand n:prop|Old_Faithful ?\n ",
#                         "gra": " %gra:\t1|2|LINK 2|0|ROOT 3|5|DET 4|5|MOD 5|2|PRED 6|2|PUNCT\n  %gra:\t1|2|LINK 2|0|ROOT 3|5|DET 4|5|MOD 5|2|PRED 6|2|PUNCT\n ",
#                         "wor": " %wor:\tw:here's \u0015194283_194843\u0015 the \u0015194843_195163\u0015 grand \u0015195163_195703\u0015 xxx &-uh \u0015196333_196343\u0015 Old_Faithful \u0015196343_199263\u0015 ?\n  \n "
#                     },
#                     {
#                         "speaker": "INV",
#                         "dialogue": "*INV:\tYellowstone . \u0015199843_200563\u0015\n ",
#                         "mor": " %mor:\tn:prop|Yellowstone .\n  %mor:\tn:prop|Yellowstone .\n ",
#                         "gra": " %gra:\t1|0|INCROOT 2|1|PUNCT\n  %gra:\t1|0|INCROOT 2|1|PUNCT\n ",
#                         "wor": " %wor:\tYellowstone \u0015199843_200563\u0015 .\n  \n "
#                     },
#                     {
#                         "speaker": "PAR",
#                         "dialogue": "*PAR:\tI went so\u028am\u026alb\u026al@u [: snowmobile] [* n:k] ridin(g) in &snel &l &l\n  \tYellowstone national park . \u0015200968_213188\u0015\n ",
#                         "mor": " %mor:\tpro:sub|I v|go&PAST n|+n|snow+n|mobile part|ride-PRESP prep|in\n  %mor:\tpro:sub|I v|go&PAST n|+n|snow+n|mobile part|ride-PRESP prep|in\n  \tn:prop|Yellowstone adj|nation&dn-AL n|park .\n ",
#                         "gra": " %gra:\t1|2|SUBJ 2|0|ROOT 3|2|OBJ 4|3|XMOD 5|4|JCT 6|8|MOD 7|8|MOD 8|5|POBJ\n  %gra:\t1|2|SUBJ 2|0|ROOT 3|2|OBJ 4|3|XMOD 5|4|JCT 6|8|MOD 7|8|MOD 8|5|POBJ\n  \t9|2|PUNCT\n ",
#                         "wor": " %wor:\tI \u0015200968_201228\u0015 went \u0015201228_201858\u0015 so\u028am\u026alb\u026al@u [: snowmobile] [* n:k] \u0015202358_204568\u0015 ridin(g) \u0015205438_206478\u0015 in \u0015206508_207168\u0015 &snel &l &l  Yellowstone \u0015207438_208108\u0015 national \u0015208488_208948\u0015 park \u0015212888_213188\u0015 .\n  \n "
#                     },
#                     {
#                         "speaker": "INV",
#                         "dialogue": "*INV:\tso \u2021 you went snowmobile riding ! \u0015213940_217430\u0015\n ",
#                         "mor": " %mor:\tco|so beg|beg pro:per|you v|go&PAST n|+n|snow+n|mobile\n  %mor:\tco|so beg|beg pro:per|you v|go&PAST n|+n|snow+n|mobile\n  \tpart|ride-PRESP !\n ",
#                         "gra": " %gra:\t1|0|BEG 2|1|BEGP 3|4|SUBJ 4|0|ROOT 5|4|OBJ 6|5|XMOD 7|4|PUNCT\n  %gra:\t1|0|BEG 2|1|BEGP 3|4|SUBJ 4|0|ROOT 5|4|OBJ 6|5|XMOD 7|4|PUNCT\n ",
#                         "wor": " %wor:\tso \u2021 you \u0015213940_214150\u0015 went \u0015214150_214490\u0015 snowmobile \u0015215360_216990\u0015 riding \u0015216990_217430\u0015 !\n  \n "
#                     },
#                     {
#                         "speaker": "PAR",
#                         "dialogue": "*PAR:\t+< right . \u0015217385_217725\u0015\n ",
#                         "mor": " %mor:\tco|right .\n  %mor:\tco|right .\n ",
#                         "gra": " %gra:\t1|0|INCROOT 2|1|PUNCT\n  %gra:\t1|0|INCROOT 2|1|PUNCT\n ",
#                         "wor": " %wor:\t+< right \u0015217385_217725\u0015 .\n  \n "
#                     },
#                     {
#                         "speaker": "INV",
#                         "dialogue": "*INV:\t<in &Yellows> [//] oh: did you ! \u0015218088_220538\u0015\n ",
#                         "mor": " %mor:\tco|oh mod|do&PAST pro:per|you !\n  %mor:\tco|oh mod|do&PAST pro:per|you !\n ",
#                         "gra": " %gra:\t1|3|COM 2|3|AUX 3|0|INCROOT 4|3|PUNCT\n  %gra:\t1|3|COM 2|3|AUX 3|0|INCROOT 4|3|PUNCT\n ",
#                         "wor": " %wor:\t<in \u0015218088_218368\u0015 &Yellows> [//] oh: did you ! \u0015218368_220538\u0015\n  \n "
#                     },
#                     {
#                         "speaker": "PAR",
#                         "dialogue": "*PAR:\t+< I seen [: saw] [* m:sub:ed] bald eagles . [+ gram] \u0015221478_222928\u0015\n ",
#                         "mor": " %mor:\tpro:sub|I n|saw adj|bald n|eagle-PL .\n  %mor:\tpro:sub|I n|saw adj|bald n|eagle-PL .\n ",
#                         "gra": " %gra:\t1|2|SUBJ 2|4|MOD 3|4|MOD 4|0|INCROOT 5|4|PUNCT\n  %gra:\t1|2|SUBJ 2|4|MOD 3|4|MOD 4|0|INCROOT 5|4|PUNCT\n ",
#                         "wor": " %wor:\t+< I \u0015221478_221488\u0015 seen [: saw] [* m:sub:ed] \u0015221488_221598\u0015 bald \u0015221598_222228\u0015 eagles \u0015222228_222928\u0015 . [+ gram]\n  \n "
#                     },
#                     {
#                         "speaker": "PAR",
#                         "dialogue": "*PAR:\tI seen [: saw] [* m:sub:ed] all the animals . [+ gram] \u0015223413_226353\u0015\n ",
#                         "mor": " %mor:\tpro:sub|I v|see&PAST qn|all det:art|the n|animal-PL .\n  %mor:\tpro:sub|I v|see&PAST qn|all det:art|the n|animal-PL .\n ",
#                         "gra": " %gra:\t1|2|SUBJ 2|0|ROOT 3|5|QUANT 4|5|DET 5|2|OBJ 6|2|PUNCT\n  %gra:\t1|2|SUBJ 2|0|ROOT 3|5|QUANT 4|5|DET 5|2|OBJ 6|2|PUNCT\n ",
#                         "wor": " %wor:\tI \u0015223413_224523\u0015 seen [: saw] [* m:sub:ed] \u0015224553_224693\u0015 all \u0015224723_225193\u0015 the \u0015225193_225213\u0015 animals \u0015225213_226353\u0015 . [+ gram]\n  \n "
#                     },
#                     {
#                         "speaker": "INV",
#                         "dialogue": "*INV:\tsuch as +..? \u0015227435_228455\u0015\n ",
#                         "mor": " %mor:\tqn|such adv|as +..?\n  %mor:\tqn|such adv|as +..?\n ",
#                         "gra": " %gra:\t1|2|QUANT 2|0|INCROOT 3|2|PUNCT\n  %gra:\t1|2|QUANT 2|0|INCROOT 3|2|PUNCT\n ",
#                         "wor": " %wor:\tsuch \u0015227435_227715\u0015 as \u0015227715_228455\u0015 +..?\n  \n "
#                     },
#                     {
#                         "speaker": "PAR",
#                         "dialogue": "*PAR:\t++ bears &-uh elk &-uh moose &-uh &s foxes . [+ gram] \u0015229160_237420\u0015\n ",
#                         "mor": " %mor:\tv|bear-3S n|elk n|moose n|fox-PL .\n  %mor:\tv|bear-3S n|elk n|moose n|fox-PL .\n ",
#                         "gra": " %gra:\t1|0|ROOT 2|4|MOD 3|4|MOD 4|1|OBJ 5|1|PUNCT\n  %gra:\t1|0|ROOT 2|4|MOD 3|4|MOD 4|1|OBJ 5|1|PUNCT\n ",
#                         "wor": " %wor:\t++ bears \u0015229160_230190\u0015 &-uh \u0015230930_231140\u0015 elk \u0015231480_232190\u0015 &-uh \u0015233100_233110\u0015 moose \u0015233110_234360\u0015 &-uh \u0015235160_235560\u0015 &s foxes \u0015235560_237420\u0015 . [+ gram]\n  \n "
#                     },
#                     {
#                         "speaker": "INV",
#                         "dialogue": "*INV:\tmhm . \u0015237805_237995\u0015\n ",
#                         "mor": " %mor:\tco|mhm=yes .\n  %mor:\tco|mhm=yes .\n ",
#                         "gra": " %gra:\t1|0|INCROOT 2|1|PUNCT\n  %gra:\t1|0|INCROOT 2|1|PUNCT\n ",
#                         "wor": " %wor:\tmhm \u0015237805_237995\u0015 .\n  \n "
#                     },
#                     {
#                         "speaker": "PAR",
#                         "dialogue": "*PAR:\t&-uh you [//] we come up &-uh one &d &-uh dozen bag [: black]\n  \t[* s:ur] d\u0279\u025b\u0279z@u [: bears] [* p:n] in the road sunnin(g) theirself\n  \t[: themselves] [* m:0s] . [+ gram] \u0015239125_254615\u0015\n ",
#                         "mor": " %mor:\tpro:sub|we v|come adv|up det:num|one n|dozen adj|black n|bear-PL\n  %mor:\tpro:sub|we v|come adv|up det:num|one n|dozen adj|black n|bear-PL\n  \tprep|in det:art|the n|road part|sun-PRESP pro:refl|themselves .\n ",
#                         "gra": " %gra:\t1|2|SUBJ 2|0|ROOT 3|2|JCT 4|5|QUANT 5|7|MOD 6|7|MOD 7|2|JCT 8|2|JCT\n  %gra:\t1|2|SUBJ 2|0|ROOT 3|2|JCT 4|5|QUANT 5|7|MOD 6|7|MOD 7|2|JCT 8|2|JCT\n  \t9|10|DET 10|8|POBJ 11|2|XJCT 12|11|OBJ 13|2|PUNCT\n ",
#                         "wor": " %wor:\t&-uh \u0015239125_239195\u0015 you [//] \u0015240495_241155\u0015 we \u0015243175_243415\u0015 come \u0015243415_243975\u0015 up \u0015243975_244345\u0015 &-uh \u0015244795_244935\u0015 one \u0015244935_245905\u0015 &d &-uh \u0015247235_247465\u0015 dozen \u0015247465_248615\u0015 bag [: black]  [* s:ur] \u0015248825_249305\u0015 d\u0279\u025b\u0279z@u [: bears] [* p:n] \u0015249305_250125\u0015 in \u0015251545_251875\u0015 the \u0015251875_251885\u0015 road \u0015251885_252615\u0015 sunnin(g) \u0015253035_254005\u0015 theirself  [: themselves] [* m:0s] \u0015254005_254615\u0015 . [+ gram]\n  \n "
#                     },
#                     {
#                         "speaker": "INV",
#                         "dialogue": "*INV:\t&=laughs oh: . \u0015254856_255816\u0015\n ",
#                         "mor": " %mor:\tco|oh .\n  %mor:\tco|oh .\n ",
#                         "gra": " %gra:\t1|0|INCROOT 2|1|PUNCT\n  %gra:\t1|0|INCROOT 2|1|PUNCT\n ",
#                         "wor": " %wor:\t&=laughs oh: \u0015254856_255816\u0015 .\n  \n "
#                     },
#                     {
#                         "speaker": "PAR",
#                         "dialogue": "*PAR:\tand you +/. \u0015256055_256904\u0015\n ",
#                         "mor": " %mor:\tcoord|and pro:per|you +/.\n  %mor:\tcoord|and pro:per|you +/.\n ",
#                         "gra": " %gra:\t1|2|LINK 2|0|INCROOT 3|2|PUNCT\n  %gra:\t1|2|LINK 2|0|INCROOT 3|2|PUNCT\n ",
#                         "wor": " %wor:\tand \u0015256055_256145\u0015 you \u0015256145_256905\u0015 +/.\n  \n "
#                     },
#                     {
#                         "speaker": "INV",
#                         "dialogue": "*INV:\ta rattler . \u0015256920_257810\u0015\n ",
#                         "mor": " %mor:\tdet:art|a n|rattler .\n  %mor:\tdet:art|a n|rattler .\n ",
#                         "gra": " %gra:\t1|2|DET 2|0|INCROOT 3|2|PUNCT\n  %gra:\t1|2|DET 2|0|INCROOT 3|2|PUNCT\n ",
#                         "wor": " %wor:\ta \u0015256920_256950\u0015 rattler \u0015256950_257810\u0015 .\n  \n "
#                     },
#                     {
#                         "speaker": "PAR",
#                         "dialogue": "*PAR:\t+, you can't go off the road with a s\u0259\u0261omo\u028a@u [: snowmobile]\n  \t[* n:k] . \u0015258463_264673\u0015\n ",
#                         "mor": " %mor:\tpro:per|you mod|can~neg|not v|go prep|off det:art|the n|road\n  %mor:\tpro:per|you mod|can~neg|not v|go prep|off det:art|the n|road\n  \tprep|with det:art|a n|+n|snow+n|mobile .\n ",
#                         "gra": " %gra:\t1|4|SUBJ 2|4|AUX 3|2|NEG 4|0|ROOT 5|4|JCT 6|7|DET 7|5|POBJ 8|4|JCT\n  %gra:\t1|4|SUBJ 2|4|AUX 3|2|NEG 4|0|ROOT 5|4|JCT 6|7|DET 7|5|POBJ 8|4|JCT\n  \t9|10|DET 10|8|POBJ 11|4|PUNCT\n ",
#                         "wor": " %wor:\t+, you \u0015258463_259393\u0015 can't \u0015259513_260183\u0015 go \u0015261223_261583\u0015 off \u0015261583_262013\u0015 the \u0015262013_262123\u0015 road \u0015262123_263183\u0015 with \u0015263183_263503\u0015 a \u0015263503_263633\u0015 s\u0259\u0261omo\u028a@u [: snowmobile]  [* n:k] \u0015263633_264673\u0015 .\n  \n "
#                     },
#                     {
#                         "speaker": "PAR",
#                         "dialogue": "*PAR:\tyou gotta rate [: wait] [* p:w] there until <they said> [//] dice\n  \t[//] they move . \u0015265135_271755\u0015\n ",
#                         "mor": " %mor:\tpro:per|you mod|got~inf|to v|wait adv|there prep|until pro:sub|they\n  %mor:\tpro:per|you mod|got~inf|to v|wait adv|there prep|until pro:sub|they\n  \tv|move .\n ",
#                         "gra": " %gra:\t1|4|SUBJ 2|4|AUX 3|4|INF 4|0|ROOT 5|4|JCT 6|8|JCT 7|8|SUBJ 8|4|CJCT\n  %gra:\t1|4|SUBJ 2|4|AUX 3|4|INF 4|0|ROOT 5|4|JCT 6|8|JCT 7|8|SUBJ 8|4|CJCT\n  \t9|4|PUNCT\n ",
#                         "wor": " %wor:\tyou \u0015265135_265385\u0015 gotta \u0015265385_265915\u0015 rate [: wait] [* p:w] \u0015265945_266605\u0015 there \u0015266605_266885\u0015 until \u0015266885_267825\u0015 <they \u0015267825_268175\u0015 said \u0015268175_268955\u0015> [//] dice  [//] \u0015269435_269945\u0015 they \u0015270525_270985\u0015 move \u0015271025_271755\u0015 .\n  \n "
#                     },
#                     {
#                         "speaker": "INV",
#                         "dialogue": "*INV:\tright . \u0015272475_272825\u0015\n ",
#                         "mor": " %mor:\tco|right .\n  %mor:\tco|right .\n ",
#                         "gra": " %gra:\t1|0|INCROOT 2|1|PUNCT\n  %gra:\t1|0|INCROOT 2|1|PUNCT\n ",
#                         "wor": " %wor:\tright \u0015272475_272825\u0015 .\n  \n "
#                     },
#                     {
#                         "speaker": "PAR",
#                         "dialogue": "*PAR:\tso \u2021 &=scratches:nose we was [: were] [* m:vsg:a] on one side of\n  \t(th)em . [+ gram] \u0015274328_277898\u0015\n ",
#                         "mor": " %mor:\tco|so beg|beg pro:sub|we cop|be&PAST prep|on det:num|one n|side\n  %mor:\tco|so beg|beg pro:sub|we cop|be&PAST prep|on det:num|one n|side\n  \tprep|of pro:obj|them .\n ",
#                         "gra": " %gra:\t1|0|BEG 2|1|BEGP 3|4|SUBJ 4|0|ROOT 5|4|JCT 6|7|QUANT 7|5|POBJ 8|7|NJCT\n  %gra:\t1|0|BEG 2|1|BEGP 3|4|SUBJ 4|0|ROOT 5|4|JCT 6|7|QUANT 7|5|POBJ 8|7|NJCT\n  \t9|8|POBJ 10|4|PUNCT\n ",
#                         "wor": " %wor:\tso \u2021 &=scratches:nose we \u0015274328_274518\u0015 was [: were] [* m:vsg:a] \u0015274518_274908\u0015 on \u0015274908_276438\u0015 one \u0015276438_276808\u0015 side \u0015276808_277438\u0015 of \u0015277438_277598\u0015  (th)em \u0015277598_277898\u0015 . [+ gram]\n  \n "
#                     },
#                     {
#                         "speaker": "PAR",
#                         "dialogue": "*PAR:\tand &-uh &-uh some riders &o on the other side . [+ gram] \u0015278608_285188\u0015\n ",
#                         "mor": " %mor:\tcoord|and qn|some n|ride&dv-AGT-PL prep|on det:art|the qn|other\n  %mor:\tcoord|and qn|some n|ride&dv-AGT-PL prep|on det:art|the qn|other\n  \tn|side .\n ",
#                         "gra": " %gra:\t1|3|LINK 2|3|QUANT 3|0|INCROOT 4|3|NJCT 5|7|DET 6|7|QUANT 7|4|POBJ\n  %gra:\t1|3|LINK 2|3|QUANT 3|0|INCROOT 4|3|NJCT 5|7|DET 6|7|QUANT 7|4|POBJ\n  \t8|3|PUNCT\n ",
#                         "wor": " %wor:\tand \u0015278608_279128\u0015 &-uh \u0015279128_279378\u0015 &-uh \u0015280258_280428\u0015 some \u0015280958_281698\u0015 riders \u0015282028_283038\u0015 &o on \u0015283038_283798\u0015 the \u0015283798_283878\u0015 other \u0015283878_284618\u0015 side \u0015284618_285188\u0015 . [+ gram]\n  \n "
#                     },
#                     {
#                         "speaker": "PAR",
#                         "dialogue": "*PAR:\tand we sat there for forty five minutes . \u0015285808_290878\u0015\n ",
#                         "mor": " %mor:\tcoord|and pro:sub|we v|sit&PAST adv|there prep|for det:num|forty\n  %mor:\tcoord|and pro:sub|we v|sit&PAST adv|there prep|for det:num|forty\n  \tdet:num|five n|minute-PL .\n ",
#                         "gra": " %gra:\t1|3|LINK 2|3|SUBJ 3|0|ROOT 4|3|JCT 5|3|JCT 6|8|QUANT 7|8|QUANT 8|5|POBJ\n  %gra:\t1|3|LINK 2|3|SUBJ 3|0|ROOT 4|3|JCT 5|3|JCT 6|8|QUANT 7|8|QUANT 8|5|POBJ\n  \t9|3|PUNCT\n ",
#                         "wor": " %wor:\tand \u0015285808_286208\u0015 we \u0015286208_286458\u0015 sat \u0015286458_287198\u0015 there \u0015287198_287668\u0015 for \u0015288158_288638\u0015 forty \u0015288638_289458\u0015 five \u0015289458_290148\u0015 minutes \u0015290148_290878\u0015 .\n  \n "
#                     },
#                     {
#                         "speaker": "PAR",
#                         "dialogue": "*PAR:\tand they &n didn't duv@u [: move] [* p:n] . \u0015291243_293103\u0015\n ",
#                         "mor": " %mor:\tcoord|and pro:sub|they mod|do&PAST~neg|not v|move .\n  %mor:\tcoord|and pro:sub|they mod|do&PAST~neg|not v|move .\n ",
#                         "gra": " %gra:\t1|5|LINK 2|5|SUBJ 3|5|AUX 4|3|NEG 5|0|ROOT 6|5|PUNCT\n  %gra:\t1|5|LINK 2|5|SUBJ 3|5|AUX 4|3|NEG 5|0|ROOT 6|5|PUNCT\n ",
#                         "wor": " %wor:\tand \u0015291243_291673\u0015 they \u0015291673_291953\u0015 &n didn't \u0015291953_292713\u0015 duv@u [: move] [* p:n] \u0015292713_293103\u0015 .\n  \n "
#                     },
#                     {
#                         "speaker": "PAR",
#                         "dialogue": "*PAR:\tso +/.\n ",
#                         "mor": " %mor:\tco|so +/.\n  %mor:\tco|so +/.\n ",
#                         "gra": " %gra:\t1|0|INCROOT 2|1|PUNCT\n  %gra:\t1|0|INCROOT 2|1|PUNCT\n ",
#                         "wor": " %wor:\tso +/.\n  \n "
#                     },
#                     {
#                         "speaker": "INV",
#                         "dialogue": "*INV:\tnow wait what was this in the middle of the road ? \u0015294218_296378\u0015\n ",
#                         "mor": " %mor:\tadv:tem|now v|wait pro:int|what cop|be&PAST&13S det:dem|this\n  %mor:\tadv:tem|now v|wait pro:int|what cop|be&PAST&13S det:dem|this\n  \tprep|in det:art|the n|middle prep|of det:art|the n|road ?\n ",
#                         "gra": " %gra:\t1|2|SUBJ 2|0|ROOT 3|4|SUBJ 4|2|COMP 5|4|PRED 6|5|JCT 7|8|DET 8|6|POBJ\n  %gra:\t1|2|SUBJ 2|0|ROOT 3|4|SUBJ 4|2|COMP 5|4|PRED 6|5|JCT 7|8|DET 8|6|POBJ\n  \t9|8|NJCT 10|11|DET 11|9|POBJ 12|2|PUNCT\n ",
# ...
#                     },
#                     {
#                         "speaker": "PAR",
#                         "dialogue": "*PAR:\tand &-uh you put a &=ges:coat nice cold [* s:uk] . [+ jar] \u0015836257_837987\u0015\n ",
#                         "mor": " %mor:\tcoord|and pro:per|you v|put&ZERO det:art|a adj|nice n|cold .\n  %mor:\tcoord|and pro:per|you v|put&ZERO det:art|a adj|nice n|cold .\n ",
#                         "gra": " %gra:\t1|3|LINK 2|3|SUBJ 3|0|ROOT 4|6|DET 5|6|MOD 6|3|OBJ 7|3|PUNCT\n  %gra:\t1|3|LINK 2|3|SUBJ 3|0|ROOT 4|6|DET 5|6|MOD 6|3|OBJ 7|3|PUNCT\n ",
#                         "wor": " %wor:\tand \u0015836257_836537\u0015 &-uh \u0015836847_836857\u0015 you \u0015836857_836927\u0015 put \u0015836987_837307\u0015 a \u0015837367_837397\u0015 &=ges:coat nice \u0015837397_837707\u0015 cold [* s:uk] \u0015837707_837987\u0015 . [+ jar]\n  \n "
#                     },
#                     {
#                         "speaker": "PAR",
#                         "dialogue": "*PAR:\t&=ges:coat I like all xxx . [+ jar] \u0015838123_839343\u0015\n ",
#                         "mor": " %mor:\tpro:sub|I v|like adv|all .\n  %mor:\tpro:sub|I v|like adv|all .\n ",
#                         "gra": " %gra:\t1|2|SUBJ 2|0|ROOT 3|2|JCT 4|2|PUNCT\n  %gra:\t1|2|SUBJ 2|0|ROOT 3|2|JCT 4|2|PUNCT\n ",
#                         "wor": " %wor:\t&=ges:coat I \u0015838123_838213\u0015 like \u0015838213_838603\u0015 all \u0015838603_839343\u0015 xxx . [+ jar]\n  \n "
#                     },
#                     {
#                         "speaker": "PAR",
#                         "dialogue": "*PAR:\t&=shows:arms that's nice . [+ es] \u0015839519_840249\u0015\n ",
#                         "mor": " %mor:\tpro:dem|that~cop|be&3S adj|nice .\n  %mor:\tpro:dem|that~cop|be&3S adj|nice .\n ",
#                         "gra": " %gra:\t1|2|SUBJ 2|0|ROOT 3|2|PRED 4|2|PUNCT\n  %gra:\t1|2|SUBJ 2|0|ROOT 3|2|PRED 4|2|PUNCT\n ",
#                         "wor": " %wor:\t&=shows:arms that's \u0015839519_839879\u0015 nice \u0015839879_840249\u0015 . [+ es]\n  \n "
#                     },
#                     {
#                         "speaker": "PAR",
#                         "dialogue": "*PAR:\t&=shows:arms nice k\u028cl@u [: x@n] [* n:uk] . [+ jar] \u0015841049_841379\u0015\n ",
#                         "mor": " %mor:\tadj|nice neo|x .\n  %mor:\tadj|nice neo|x .\n ",
#                         "gra": " %gra:\t1|2|MOD 2|0|INCROOT 3|2|PUNCT\n  %gra:\t1|2|MOD 2|0|INCROOT 3|2|PUNCT\n ",
#                         "wor": " %wor:\t&=shows:arms nice \u0015841049_841279\u0015 k\u028cl@u [: x@n] [* n:uk] \u0015841279_841379\u0015 . [+ jar]\n  \n "
#                     },
#                     {
#                         "speaker": "INV",
#                         "dialogue": "*INV:\tmhm . \u0015841755_842085\u0015\n ",
#                         "mor": " %mor:\tco|mhm=yes .\n  %mor:\tco|mhm=yes .\n ",
#                         "gra": " %gra:\t1|0|INCROOT 2|1|PUNCT\n  %gra:\t1|0|INCROOT 2|1|PUNCT\n ",
#                         "wor": " %wor:\tmhm \u0015841755_842085\u0015 .\n  \n "
#                     },
#                     {
#                         "speaker": "PAR",
#                         "dialogue": "*PAR:\t+< I have &=points:self that hole [* s:uk] when I get holts@u\n  \t[: x@n] [* n:uk] . \u0015841755_843495\u0015\n ",
#                         "mor": " %mor:\tpro:sub|I v|have det:dem|that n|hole conj|when pro:sub|I v|get\n  %mor:\tpro:sub|I v|have det:dem|that n|hole conj|when pro:sub|I v|get\n  \tneo|x .\n ",
#                         "gra": " %gra:\t1|2|SUBJ 2|0|ROOT 3|4|DET 4|2|OBJ 5|7|LINK 6|7|SUBJ 7|2|CJCT 8|7|OBJ\n  %gra:\t1|2|SUBJ 2|0|ROOT 3|4|DET 4|2|OBJ 5|7|LINK 6|7|SUBJ 7|2|CJCT 8|7|OBJ\n  \t9|2|PUNCT\n ",
#                         "wor": " %wor:\t+< I \u0015841755_841865\u0015 have \u0015841865_842165\u0015 &=points:self that \u0015842165_842395\u0015 hole [* s:uk] \u0015842395_842545\u0015 when \u0015842545_842775\u0015 I \u0015842775_842885\u0015 get holts@u  [: x@n] [* n:uk] \u0015843445_843495\u0015 .\n  \n "
#                     },
#                     {
#                         "speaker": "INV",
#                         "dialogue": "*INV:\toh yeah . \u0015843570_844600\u0015\n ",
#                         "mor": " %mor:\tco|oh co|yeah .\n  %mor:\tco|oh co|yeah .\n ",
#                         "gra": " %gra:\t1|2|COM 2|0|INCROOT 3|2|PUNCT\n  %gra:\t1|2|COM 2|0|INCROOT 3|2|PUNCT\n ",
#                         "wor": " %wor:\toh \u0015843570_844080\u0015 yeah \u0015844080_844600\u0015 .\n  \n "
#                     },
#                     {
#                         "speaker": "INV",
#                         "dialogue": "*INV:\tI've [/] I've have seen it . \u0015844717_846397\u0015\n ",
#                         "mor": " %mor:\tpro:sub|I~aux|have aux|have part|see&PASTP pro:per|it .\n  %mor:\tpro:sub|I~aux|have aux|have part|see&PASTP pro:per|it .\n ",
#                         "gra": " %gra:\t1|4|SUBJ 2|4|AUX 3|4|AUX 4|0|ROOT 5|4|OBJ 6|4|PUNCT\n  %gra:\t1|4|SUBJ 2|4|AUX 3|4|AUX 4|0|ROOT 5|4|OBJ 6|4|PUNCT\n ",
#                         "wor": " %wor:\tI've [/] \u0015844717_845007\u0015 I've \u0015845197_845577\u0015 have \u0015845767_846037\u0015 seen \u0015846037_846327\u0015 it \u0015846327_846397\u0015 .\n  \n "
#                     },
#                     {
#                         "speaker": "PAR",
#                         "dialogue": "*PAR:\t+< yeah . \u0015846328_846329\u0015\n ",
#                         "mor": " %mor:\tco|yeah .\n  %mor:\tco|yeah .\n ",
#                         "gra": " %gra:\t1|0|INCROOT 2|1|PUNCT\n  %gra:\t1|0|INCROOT 2|1|PUNCT\n ",
#                         "wor": " %wor:\t+< yeah \u0015846179_846259\u0015 .\n  \n "
#                     },
#                     {
#                         "speaker": "INV",
#                         "dialogue": "*INV:\tthat's right . \u0015846700_847120\u0015\n ",
#                         "mor": " %mor:\tpro:dem|that~cop|be&3S co|right .\n  %mor:\tpro:dem|that~cop|be&3S co|right .\n ",
#                         "gra": " %gra:\t1|2|SUBJ 2|0|ROOT 3|2|PRED 4|2|PUNCT\n  %gra:\t1|2|SUBJ 2|0|ROOT 3|2|PRED 4|2|PUNCT\n ",
#                         "wor": " %wor:\tthat's \u0015846700_846910\u0015 right \u0015846910_847120\u0015 .\n  \n "
#                     },
#                     {
#                         "speaker": "PAR",
#                         "dialogue": "*PAR:\t+< yeah [/] yeah . \u0015846911_847500\u0015\n ",
#                         "mor": " %mor:\tco|yeah .\n  %mor:\tco|yeah .\n ",
#                         "gra": " %gra:\t1|0|INCROOT 2|1|PUNCT\n  %gra:\t1|0|INCROOT 2|1|PUNCT\n ",
#                         "wor": " %wor:\t+< yeah [/] \u0015846840_847180\u0015 yeah \u0015847330_847500\u0015 .\n  \n "
#                     },
#                     {
#                         "speaker": "INV",
#                         "dialogue": "*INV:\t+< mhm . \u0015847365_847755\u0015\n ",
#                         "mor": " %mor:\tco|mhm=yes .\n  %mor:\tco|mhm=yes .\n ",
#                         "gra": " %gra:\t1|0|INCROOT 2|1|PUNCT\n  %gra:\t1|0|INCROOT 2|1|PUNCT\n ",
#                         "wor": " %wor:\t+< mhm \u0015847365_847755\u0015 .\n  \n "
#                     },
#                     {
#                         "speaker": "INV",
#                         "dialogue": "*INV:\tyep . \u0015848531_848711\u0015\n ",
#                         "mor": " %mor:\tco|yep .\n  %mor:\tco|yep .\n ",
#                         "gra": " %gra:\t1|0|INCROOT 2|1|PUNCT\n  %gra:\t1|0|INCROOT 2|1|PUNCT\n ",
#                         "wor": " %wor:\tyep \u0015848531_848711\u0015 .\n  \n "
#                     },
#                     {
#                         "speaker": "PAR",
#                         "dialogue": "*PAR:\t&=head:yes yeah . \u0015849160_849250\u0015\n ",
#                         "mor": " %mor:\tco|yeah .\n  %mor:\tco|yeah .\n ",
#                         "gra": " %gra:\t1|0|INCROOT 2|1|PUNCT\n  %gra:\t1|0|INCROOT 2|1|PUNCT\n ",
#                         "wor": " %wor:\t&=head:yes yeah \u0015849160_849250\u0015 .\n  \n "
#                     },
#                     {
#                         "speaker": "INV",
#                         "dialogue": "*INV:\t+< so \u2021 it was a good trip . \u0015849230_850130\u0015\n ",
#                         "mor": " %mor:\tco|so beg|beg pro:per|it cop|be&PAST&13S det:art|a adj|good n|trip\n  %mor:\tco|so beg|beg pro:per|it cop|be&PAST&13S det:art|a adj|good n|trip\n  \t.\n ",
#                         "gra": " %gra:\t1|0|BEG 2|1|BEGP 3|4|SUBJ 4|0|ROOT 5|7|DET 6|7|MOD 7|4|PRED 8|4|PUNCT\n  %gra:\t1|0|BEG 2|1|BEGP 3|4|SUBJ 4|0|ROOT 5|7|DET 6|7|MOD 7|4|PRED 8|4|PUNCT\n ",
#                         "wor": " %wor:\t+< so \u0015849230_849320\u0015 \u2021 it \u0015849320_849390\u0015 was \u0015849390_849530\u0015 a \u0015849530_849580\u0015 good \u0015849580_849810\u0015 trip \u0015849810_850130\u0015 .\n  \n "
#                     },
#                     {
#                         "speaker": "PAR",
#                         "dialogue": "*PAR:\tyep . \u0015850584_850704\u0015\n ",
#                         "mor": " %mor:\tco|yep .\n  %mor:\tco|yep .\n ",
#                         "gra": " %gra:\t1|0|INCROOT 2|1|PUNCT\n  %gra:\t1|0|INCROOT 2|1|PUNCT\n ",
#                         "wor": " %wor:\tyep \u0015850584_850704\u0015 .\n  \n "
#                     },
#                     {
#                         "speaker": "INV",
#                         "dialogue": "*INV:\tI would love to follow in your footsteps . \u0015851780_853660\u0015\n ",
#                         "mor": " %mor:\tpro:sub|I mod|will&COND v|love inf|to v|follow prep|in\n  %mor:\tpro:sub|I mod|will&COND v|love inf|to v|follow prep|in\n  \tdet:poss|your n|+n|foot+n|step-PL .\n ",
#                         "gra": " %gra:\t1|3|SUBJ 2|3|AUX 3|0|ROOT 4|5|INF 5|3|COMP 6|5|JCT 7|8|DET 8|6|POBJ\n  %gra:\t1|3|SUBJ 2|3|AUX 3|0|ROOT 4|5|INF 5|3|COMP 6|5|JCT 7|8|DET 8|6|POBJ\n  \t9|3|PUNCT\n ",
#                         "wor": " %wor:\tI \u0015851780_851870\u0015 would \u0015851870_852160\u0015 love \u0015852160_852350\u0015 to \u0015852350_852460\u0015 follow \u0015852550_852900\u0015 in \u0015852900_852990\u0015 your \u0015852990_853090\u0015 footsteps \u0015853090_853660\u0015 .\n  \n "
#                     },
#                     {
#                         "speaker": "PAR",
#                         "dialogue": "*PAR:\t+< I know . \u0015853899_854019\u0015\n ",
#                         "mor": " %mor:\tpro:sub|I v|know .\n  %mor:\tpro:sub|I v|know .\n ",
#                         "gra": " %gra:\t1|2|SUBJ 2|0|ROOT 3|2|PUNCT\n  %gra:\t1|2|SUBJ 2|0|ROOT 3|2|PUNCT\n ",
#                         "wor": " %wor:\t+< I \u0015853899_853929\u0015 know \u0015853929_854019\u0015 .\n  \n "
#                     },
#                     {
#                         "speaker": "INV",
#                         "dialogue": "*INV:\tand go there myself . \u0015853930_855786\u0015\n ",
#                         "mor": " %mor:\tcoord|and v|go adv|there pro:refl|myself .\n  %mor:\tcoord|and v|go adv|there pro:refl|myself .\n ",
#                         "gra": " %gra:\t1|2|LINK 2|0|ROOT 3|2|JCT 4|2|JCT 5|2|PUNCT\n  %gra:\t1|2|LINK 2|0|ROOT 3|2|JCT 4|2|JCT 5|2|PUNCT\n ",
#                         "wor": " %wor:\tand \u0015853676_854236\u0015 go \u0015854236_854766\u0015 there \u0015854766_855066\u0015 myself \u0015855066_855786\u0015 .\n  \n "
#                     },
#                     {
#                         "speaker": "PAR",
#                         "dialogue": "*PAR:\t+< I know you like to go there . \u0015855067_855608\u0015\n ",
#                         "mor": " %mor:\tpro:sub|I v|know pro:per|you v|like inf|to v|go adv|there .\n  %mor:\tpro:sub|I v|know pro:per|you v|like inf|to v|go adv|there .\n ",
#                         "gra": " %gra:\t1|2|SUBJ 2|0|ROOT 3|4|SUBJ 4|2|COMP 5|6|INF 6|4|COMP 7|6|JCT 8|2|PUNCT\n  %gra:\t1|2|SUBJ 2|0|ROOT 3|4|SUBJ 4|2|COMP 5|6|INF 6|4|COMP 7|6|JCT 8|2|PUNCT\n ",
#                         "wor": " %wor:\t+< I \u0015854288_854548\u0015 know \u0015854548_854748\u0015 you \u0015854748_854808\u0015 like \u0015854808_855058\u0015 to \u0015855058_855188\u0015 go \u0015855188_855248\u0015 there \u0015855248_855608\u0015 .\n  \n "
#                     },
#                     {
#                         "speaker": "INV",
#                         "dialogue": "*INV:\t+< I tell you . \u0015855892_856542\u0015\n ",
#                         "mor": " %mor:\tpro:sub|I v|tell pro:per|you .\n  %mor:\tpro:sub|I v|tell pro:per|you .\n ",
#                         "gra": " %gra:\t1|2|SUBJ 2|0|ROOT 3|2|OBJ 4|2|PUNCT\n  %gra:\t1|2|SUBJ 2|0|ROOT 3|2|OBJ 4|2|PUNCT\n ",
#                         "wor": " %wor:\t+< I \u0015855892_856042\u0015 tell \u0015856042_856332\u0015 you \u0015856332_856542\u0015 .\n  \n "
#                     },
#                     {
#                         "speaker": "PAR",
#                         "dialogue": "*PAR:\tI love to go . \u0015856806_857526\u0015\n ",
#                         "mor": " %mor:\tpro:sub|I v|love inf|to v|go .\n  %mor:\tpro:sub|I v|love inf|to v|go .\n ",
#                         "gra": " %gra:\t1|2|SUBJ 2|0|ROOT 3|4|INF 4|2|COMP 5|2|PUNCT\n  %gra:\t1|2|SUBJ 2|0|ROOT 3|4|INF 4|2|COMP 5|2|PUNCT\n ",
#                         "wor": " %wor:\tI \u0015856806_856976\u0015 love \u0015856976_857226\u0015 to \u0015857226_857326\u0015 go \u0015857406_857526\u0015 .\n  \n "
#                     },
#                     {
#                         "speaker": "PAR",
#                         "dialogue": "*PAR:\t<I'd like to go in> [//] I'd like to go &=points next time . \u0015857941_860081\u0015\n ",
#                         "mor": " %mor:\tpro:sub|I~mod|genmod v|like inf|to v|go adj|next n|time .\n  %mor:\tpro:sub|I~mod|genmod v|like inf|to v|go adj|next n|time .\n ",
#                         "gra": " %gra:\t1|3|SUBJ 2|3|AUX 3|0|ROOT 4|5|INF 5|3|COMP 6|7|MOD 7|5|OBJ 8|3|PUNCT\n  %gra:\t1|3|SUBJ 2|3|AUX 3|0|ROOT 4|5|INF 5|3|COMP 6|7|MOD 7|5|OBJ 8|3|PUNCT\n ",
#                         "wor": " %wor:\t<I'd \u0015857941_858111\u0015 like \u0015858111_858291\u0015 to \u0015858291_858401\u0015 go \u0015858401_858601\u0015 in \u0015858601_858711\u0015> [//] I'd like to go &=points next time . \u0015858801_860081\u0015\n  \n "
#                     },
#                     {
#                         "speaker": "INV",
#                         "dialogue": "*INV:\tyes &=laughs . \u0015860523_861773\u0015\n ",
#                         "mor": " %mor:\tco|yes .\n  %mor:\tco|yes .\n ",
#                         "gra": " %gra:\t1|0|INCROOT 2|1|PUNCT\n  %gra:\t1|0|INCROOT 2|1|PUNCT\n ",
#                         "wor": " %wor:\tyes \u0015860523_861773\u0015 &=laughs .\n  \n "
#                     },
#                     {
#                         "speaker": "PAR",
#                         "gra": "*PAR:\t+< &=laughs .\n  %wor:\t+< &=laughs .\n  \n *PAR:\t+< &=laughs .\n  %wor:\t+< &=laughs .\n  \n *PAR:\t+< &=laughs .\n ",
#                         "wor": " %wor:\t+< &=laughs .\n  \n "
#                     },
#                     {
#                         "speaker": "INV",
#                         "dialogue": "*INV:\tokay . \u0015863121_863881\u0015\n ",
#                         "mor": " %mor:\tco|okay .\n  %mor:\tco|okay .\n ",
#                         "gra": " %gra:\t1|0|INCROOT 2|1|PUNCT\n  %gra:\t1|0|INCROOT 2|1|PUNCT\n ",
#                         "wor": " %wor:\tokay \u0015863121_863881\u0015 .\n  \n "
#                     },
#                     {
#                         "speaker": "INV",
#                         "gra": "*INV:\twww .\n  %wor:\twww .\n  %exp:\ttesting recorded, but not transcribed\n  @End\n  \n *INV:\twww .\n  %wor:\twww .\n  %exp:\ttesting recorded, but not transcribed\n  @End\n  \n *INV:\twww .\n ",
#                         "wor": " %wor:\twww .\n  %exp:\ttesting recorded, but not transcribed\n  @End\n  \n "
#                     }
#                 ]
#             }
#         }
#     ]
# }

# %% [markdown]
# ## Pauses
#
#
# 1. "+..?" or "+..." -> replace with @tpause@ | Trailing off
# 2. "(.)" -> @pause@
# 3. "(..) -> @lpause@
# 4. "(...) -> @xlpause@

# %%
def

# %% [markdown]
# ## Interruptions
# 1. "+/." or "+/?" -> replace the next dialogue and this encoding with @ipause@ and join the two dialogues of the same speaker | Interruption
# 2. "+//." or "+//?" -> remove this encoding and join the current and next dialogue
